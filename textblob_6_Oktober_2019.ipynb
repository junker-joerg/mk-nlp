# %%
import gensim
from gensim import corpora

# %%
import textblob_de

# %%
from textblob_de import TextBlobDE as TextBlob
from textblob_de import PatternParser

# %%
text = '''Flydays for Future
Als hätte es keine Klimaproteste gegeben: Schlangen von Familien am Abfertigungsschalter im Flughafen Hannover-Langenhagen. 719.000 Fluggäste wurden hier im Oktober 2018 abgefertigt, in diesem Jahr rechnet der Airport mit der gleichen Zahl. fotos: Moritz Frankenberg
Trotz aller Klimaproteste: In diesen Herbstferien fliegen genauso viele Familien vom Flughafen Hannover ab wie im Vorjahr. Aber vielfach gehen kontroverse Debatten im Familienkreis voraus. Ein Besuch in der Abflugebene des Airports. Von Conrad von Meding
Hannover. Die Schlangen an den Abfertigungsschaltern sind so lang wie immer zum Ferienauftakt. Als wären nicht Zehntausende Schüler in Schulstreik getreten, als hätte es keine Klimaproteste auch an hannoverschen Schulen gegeben – übrigens genau im zehnten Monat jetzt schon. Hurghada, Mallorca, Lanzarote, Barcelona, Heraklion, Thessaloniki sind die Flugziele auf der großen Airport-Tafel an diesem Vormittag. Und darunter: Familien mit Schulkindern, die dem Schmuddelwetter gen Süden entfliehen. Mit dem Flieger. Flydays for Future?
„Die Maschinen sind gut gebucht“, bestätigt Flughafensprecher Sönke Jacobsen den optischen Eindruck, den die Schlangen an den Check-in-Schaltern vermitteln. Etwa 719 000 Fluggäste habe der Airport im Oktober 2018 gezählt. Für diesen Oktober gehe man von „annähernd dem gleichen Niveau“ aus, genaue Zahlen gibt es erst am Monatsende.
„Klimaschutz ist wichtig – aber nicht so, dass wir dafür Urlaub opfern“: Karina Schmidt mit Tochter Aylin im Flughafen Hannover auf dem Weg nach Hurghada.	Moritz Frankenberg
Also: Nichts mit Flugscham? Macht der Bewusstseinswandel Herbstferien? Erscheint die Klimakrise weniger dramatisch, wenn man dafür Sonne und Sandstrand aufgeben müsste? „Klimaschutz ist wichtig, aber nicht so, dass wir dafür den Urlaub opfern“, sagt ganz ehrlich Karina Schmidt. Die 35-jährige Physiotherapeutin ist mit Tochter Aylin (15) unterwegs nach Hurghada, das Sonne-und-Schnorchel-Paradies am Roten Meer in Ägypten. Klimaschutz nicht so wichtig – darf man so etwas sagen in Zeiten von Klimaprotesten?
„Ja, man darf“, sagt auch eine Braunschweiger Mutter, die mit Mann und den 14- und 17-jährigen Kindern Richtung Süden eincheckt. „Ich fahre 365 Tage im Jahr mit dem Rad zur Arbeit“, sagt sie, „ich kaufe sehr bewusst Lebensmittel ein, ich werfe davon fast nichts weg, wir kaufen nicht Unmengen an Klamotten, und die Kinder haben nicht ständig die neuesten Handys. Ich lasse mir nicht unterstellen, ich sei nicht umweltbewusst.“ Allein der Drang zur Rechtfertigung zeigt: Da ist durchaus Flugscham, dieses neuzeitliche Phänomen, aber zugleich der verständliche Wille, sich wenigstens den Familienurlaub nicht auch noch von Diskussionen vermiesen zu lassen.
„Ganz ehrlich: Wenn ich das Wort Flugscham höre, kriege ich Blutdruck“: Raoul Hille, Chef des Hannover-Airports, hat mit diesem Satz im Sommer Schlagzeilen gemacht. In Deutschland gingen 0,3 Prozent des CO2 -Ausstoßes auf Inlandsflüge zurück, weltweit mache der Luftverkehr zwischen 2 und 3 Prozent der Emissionen aus. Moritz Frankenberg (Archiv)
Tatsächlich setzt ein Flug Hannover–Hurghada 1797 Kilogramm CO2 frei, pro Person, in einem durchschnittlichen Flugzeug. Weil das so abstrakt klingt: Der Wert entspricht fast der Menge CO2, die ein durchschnittliches deutsches Auto pro Jahr aus dem Auspuff bläst, bei 12 000 Kilometern Fahrleistung. Die Braunschweigerin hat also recht, dass sie mit ihrem täglichen Radfahren der Umwelt viel Dreck erspart, rechnerisch hat sie sich ihren Flug nach Hurghada verdient. Nur: Ihre Familie wird wieder zurückfliegen. Das sind dann pro Person schon 3594 Kilogramm CO2, also die Fahrleistung von zwei Familienautos. Schlaue Leute haben errechnet, der durchschnittliche Inder verbrauche 1600 Kilogramm CO2 im Jahr. Bei den Zahlen ahnt man, dass zwar das Argument richtig ist, dass Deutschland nur 2 Prozent der weltweiten CO2-Emissionen ausmacht. Aber dass jeder Einzelne durchaus etwas tun kann. Könnte.
Jahrgangsfahrt an die Côte d´Azur abgesagt: An der Schule von Anna Janßen (2. v. li.) sind die Klimaveränderungen Thema. Und auch in ihrer Familie gibt es ernsthafte Debatten. Vater Jörg Janßen (re., mit Sohn Jonas) sagt: „Deutschland allein kann das Klimaproblem nicht lösen.“ Mutter Monika (li.) ärgert sich, dass Flugtickets zu billig und Bahntickets zu teuer sind. Moritz Frankenberg
Familienwechsel. An der Schule der 16-jährigen Anna Janßen haben sie für kommendes Jahr die Jahrgangsfahrt abgeblasen. Es sollte an die Côte d´Azur gehen, per Flugzeug. Die Schule aber hatte sich gerade zur Klimaschule erklärt. Anna berichtet, die Côte-d´Azur-Tour habe „heftige Debatten“ ausgelöst, „jetzt fahren wir mit dem Zug nach Colmar ins Elsass“. Niemand sage also, die Klimabewegung der Kinder ändere nichts. Aber hätte man nicht auch mit dem Zug an die Côte fahren können? „Das ist viel teurer als die Billigtickets der Flieger“, sagt Mutter Monika Janßen (50): „Wir müssten eigentlich bereit sein, die Flüge teurer zu machen und die Bahntickets preiswerter.“
Das kann Vater Jörg Janßen (50) nicht so stehen lassen. „Solange Trump seine Klimapolitik nicht ändert, brauchen auch wir gar nichts zu verändern“, sagt er: „Deutschland allein kann das Klimaproblem nicht lösen.“ Und dass in Polen „jeder Haushalt mit Briketts heizt“ und Kreuzfahrtschiffe ohnehin viel mehr Dreck in die Luft bliesen als Flieger. Tochter und Ehefrau funkeln ihn kritisch an, man ahnt, dass diese Diskussion schon etliche Male am Familientisch geführt wurde. Jörg Janßen betreibt eine Gärtnerei, man will ihm die Liebe zur Natur nicht absprechen. Aber in der Klimadebatte hat jeder seine eigenen Argumentationen und Rechtfertigungen fürs Handeln, und jetzt will Familie Janßen ins westgriechische Patras.
Mit dem Tesla zum Flughafen: Hausarzt Karsten Müller (hier mit Sohn Vincent) hat mit seinen Kindern besprochen, welche CO2-Minderungen sinnvoll sind. Moritz Frankenberg
Auch Karsten Müller (47) ist mit Frau und Kindern unterwegs, Lanzarote ist das Ziel. Die Insel lasse sich mit dem Auto ja nun mal schlecht erreichen, sagt er, und rechnet vor: „Fliegen macht 2 bis 3 Prozent des CO2-Ausstoßes aus.“ Er ist Hautarzt, hat viel auch mit Atemwegserkrankungen zu tun. Deshalb hat er gehandelt und versucht, die Welt etwas besser zu machen. Er fährt den abgasfreien Tesla, mit dem die Familie auch zum Flughafen gekommen ist. Der Strom fürs Auto kommt aus der hauseigenen Solaranlage, sodass Müller sich das billige Argument nicht ständig anhören muss, sein Auto fahre ja mit einem Strommix, der Braunkohleabgase beinhaltet. „Ich habe mit meinen Kindern besprochen, wie wir CO2 sparen können und was sinnvoll ist“, sagt er, als er Sohn Vincent (10) an sich drückt. Dann geht es nach Lanzarote.
Man kann vielleicht sagen: Hannovers Fluggastzahlen sind noch nicht signifikant zurückgegangen in den Herbstferien 2019. Aber die Diskussionen haben zugenommen. Und das ist vielleicht schon mal ein Anfang.'''

# %%
blob = TextBlob(text)

# %%
 blob.sentences
# Out:
# [Sentence("Flydays for Future
#  Als hätte es keine Klimaproteste gegeben: Schlangen von Familien am Abfertigungsschalter im Flughafen Hannover-Langenhagen."),
#  Sentence("719.000 Fluggäste wurden hier im Oktober 2018 abgefertigt, in diesem Jahr rechnet der Airport mit der gleichen Zahl."),
#  Sentence("fotos: Moritz Frankenberg
#  Trotz aller Klimaproteste: In diesen Herbstferien fliegen genauso viele Familien vom Flughafen Hannover ab wie im Vorjahr."),
#  Sentence("Aber vielfach gehen kontroverse Debatten im Familienkreis voraus."),
#  Sentence("Ein Besuch in der Abflugebene des Airports."),
#  Sentence("Von Conrad von Meding
#  Hannover."),
#  Sentence("Die Schlangen an den Abfertigungsschaltern sind so lang wie immer zum Ferienauftakt."),
#  Sentence("Als wären nicht Zehntausende Schüler in Schulstreik getreten, als hätte es keine Klimaproteste auch an hannoverschen Schulen gegeben – übrigens genau im zehnten Monat jetzt schon."),
#  Sentence("Hurghada, Mallorca, Lanzarote, Barcelona, Heraklion, Thessaloniki sind die Flugziele auf der großen Airport-Tafel an diesem Vormittag."),
#  Sentence("Und darunter: Familien mit Schulkindern, die dem Schmuddelwetter gen Süden entfliehen."),
#  Sentence("Mit dem Flieger."),
#  Sentence("Flydays for Future?"),
#  Sentence("„Die Maschinen sind gut gebucht“, bestätigt Flughafensprecher Sönke Jacobsen den optischen Eindruck, den die Schlangen an den Check-in-Schaltern vermitteln."),
#  Sentence("Etwa 719 000 Fluggäste habe der Airport im Oktober 2018 gezählt."),
#  Sentence("Für diesen Oktober gehe man von „annähernd dem gleichen Niveau“ aus, genaue Zahlen gibt es erst am Monatsende."),
#  Sentence("„Klimaschutz ist wichtig – aber nicht so, dass wir dafür Urlaub opfern“: Karina Schmidt mit Tochter Aylin im Flughafen Hannover auf dem Weg nach Hurghada."),
#  Sentence("Moritz Frankenberg
#  Also: Nichts mit Flugscham?"),
#  Sentence("Macht der Bewusstseinswandel Herbstferien?"),
#  Sentence("Erscheint die Klimakrise weniger dramatisch, wenn man dafür Sonne und Sandstrand aufgeben müsste?"),
#  Sentence("„Klimaschutz ist wichtig, aber nicht so, dass wir dafür den Urlaub opfern“, sagt ganz ehrlich Karina Schmidt."),
#  Sentence("Die 35-jährige Physiotherapeutin ist mit Tochter Aylin (15) unterwegs nach Hurghada, das Sonne-und-Schnorchel-Paradies am Roten Meer in Ägypten."),
#  Sentence("Klimaschutz nicht so wichtig – darf man so etwas sagen in Zeiten von Klimaprotesten?"),
#  Sentence("„Ja, man darf“, sagt auch eine Braunschweiger Mutter, die mit Mann und den 14- und 17-jährigen Kindern Richtung Süden eincheckt."),
#  Sentence("„Ich fahre 365 Tage im Jahr mit dem Rad zur Arbeit“, sagt sie, „ich kaufe sehr bewusst Lebensmittel ein, ich werfe davon fast nichts weg, wir kaufen nicht Unmengen an Klamotten, und die Kinder haben nicht ständig die neuesten Handys."),
#  Sentence("Ich lasse mir nicht unterstellen, ich sei nicht umweltbewusst.“ Allein der Drang zur Rechtfertigung zeigt: Da ist durchaus Flugscham, dieses neuzeitliche Phänomen, aber zugleich der verständliche Wille, sich wenigstens den Familienurlaub nicht auch noch von Diskussionen vermiesen zu lassen."),
#  Sentence("„Ganz ehrlich: Wenn ich das Wort Flugscham höre, kriege ich Blutdruck“: Raoul Hille, Chef des Hannover-Airports, hat mit diesem Satz im Sommer Schlagzeilen gemacht."),
#  Sentence("In Deutschland gingen 0,3 Prozent des CO2 -Ausstoßes auf Inlandsflüge zurück, weltweit mache der Luftverkehr zwischen 2 und 3 Prozent der Emissionen aus."),
#  Sentence("Moritz Frankenberg (Archiv)
#  Tatsächlich setzt ein Flug Hannover–Hurghada 1797 Kilogramm CO2 frei, pro Person, in einem durchschnittlichen Flugzeug."),
#  Sentence("Weil das so abstrakt klingt: Der Wert entspricht fast der Menge CO2, die ein durchschnittliches deutsches Auto pro Jahr aus dem Auspuff bläst, bei 12 000 Kilometern Fahrleistung."),
#  Sentence("Die Braunschweigerin hat also recht, dass sie mit ihrem täglichen Radfahren der Umwelt viel Dreck erspart, rechnerisch hat sie sich ihren Flug nach Hurghada verdient."),
#  Sentence("Nur: Ihre Familie wird wieder zurückfliegen."),
#  Sentence("Das sind dann pro Person schon 3594 Kilogramm CO2, also die Fahrleistung von zwei Familienautos."),
#  Sentence("Schlaue Leute haben errechnet, der durchschnittliche Inder verbrauche 1600 Kilogramm CO2 im Jahr."),
#  Sentence("Bei den Zahlen ahnt man, dass zwar das Argument richtig ist, dass Deutschland nur 2 Prozent der weltweiten CO2-Emissionen ausmacht."),
#  Sentence("Aber dass jeder Einzelne durchaus etwas tun kann."),
#  Sentence("Könnte."),
#  Sentence("Jahrgangsfahrt an die Côte d´Azur abgesagt: An der Schule von Anna Janßen (2. v."),
#  Sentence("li.)"),
#  Sentence("sind die Klimaveränderungen Thema."),
#  Sentence("Und auch in ihrer Familie gibt es ernsthafte Debatten."),
#  Sentence("Vater Jörg Janßen (re., mit Sohn Jonas) sagt: „Deutschland allein kann das Klimaproblem nicht lösen.“ Mutter Monika (li.)"),
#  Sentence("ärgert sich, dass Flugtickets zu billig und Bahntickets zu teuer sind."),
#  Sentence("Moritz Frankenberg
#  Familienwechsel."),
#  Sentence("An der Schule der 16-jährigen Anna Janßen haben sie für kommendes Jahr die Jahrgangsfahrt abgeblasen."),
#  Sentence("Es sollte an die Côte d´Azur gehen, per Flugzeug."),
#  Sentence("Die Schule aber hatte sich gerade zur Klimaschule erklärt."),
#  Sentence("Anna berichtet, die Côte-d´Azur-Tour habe „heftige Debatten“ ausgelöst, „jetzt fahren wir mit dem Zug nach Colmar ins Elsass“."),
#  Sentence("Niemand sage also, die Klimabewegung der Kinder ändere nichts."),
#  Sentence("Aber hätte man nicht auch mit dem Zug an die Côte fahren können?"),
#  Sentence("„Das ist viel teurer als die Billigtickets der Flieger“, sagt Mutter Monika Janßen (50): „Wir müssten eigentlich bereit sein, die Flüge teurer zu machen und die Bahntickets preiswerter.“
#  Das kann Vater Jörg Janßen (50) nicht so stehen lassen."),
#  Sentence("„Solange Trump seine Klimapolitik nicht ändert, brauchen auch wir gar nichts zu verändern“, sagt er: „Deutschland allein kann das Klimaproblem nicht lösen.“ Und dass in Polen „jeder Haushalt mit Briketts heizt“ und Kreuzfahrtschiffe ohnehin viel mehr Dreck in die Luft bliesen als Flieger."),
#  Sentence("Tochter und Ehefrau funkeln ihn kritisch an, man ahnt, dass diese Diskussion schon etliche Male am Familientisch geführt wurde."),
#  Sentence("Jörg Janßen betreibt eine Gärtnerei, man will ihm die Liebe zur Natur nicht absprechen."),
#  Sentence("Aber in der Klimadebatte hat jeder seine eigenen Argumentationen und Rechtfertigungen fürs Handeln, und jetzt will Familie Janßen ins westgriechische Patras."),
#  Sentence("Mit dem Tesla zum Flughafen: Hausarzt Karsten Müller (hier mit Sohn Vincent) hat mit seinen Kindern besprochen, welche CO2-Minderungen sinnvoll sind."),
#  Sentence("Moritz Frankenberg
#  Auch Karsten Müller (47) ist mit Frau und Kindern unterwegs, Lanzarote ist das Ziel."),
#  Sentence("Die Insel lasse sich mit dem Auto ja nun mal schlecht erreichen, sagt er, und rechnet vor: „Fliegen macht 2 bis 3 Prozent des CO2-Ausstoßes aus.“ Er ist Hautarzt, hat viel auch mit Atemwegserkrankungen zu tun."),
#  Sentence("Deshalb hat er gehandelt und versucht, die Welt etwas besser zu machen."),
#  Sentence("Er fährt den abgasfreien Tesla, mit dem die Familie auch zum Flughafen gekommen ist."),
#  Sentence("Der Strom fürs Auto kommt aus der hauseigenen Solaranlage, sodass Müller sich das billige Argument nicht ständig anhören muss, sein Auto fahre ja mit einem Strommix, der Braunkohleabgase beinhaltet."),
#  Sentence("„Ich habe mit meinen Kindern besprochen, wie wir CO2 sparen können und was sinnvoll ist“, sagt er, als er Sohn Vincent (10) an sich drückt."),
#  Sentence("Dann geht es nach Lanzarote."),
#  Sentence("Man kann vielleicht sagen: Hannovers Fluggastzahlen sind noch nicht signifikant zurückgegangen in den Herbstferien 2019."),
#  Sentence("Aber die Diskussionen haben zugenommen."),
#  Sentence("Und das ist vielleicht schon mal ein Anfang.")]

# %%
blob.noun_phrases
# Out:
# WordList(['es keine Klimaproteste', 'Flughafen Hannover-Langenhagen', '719.000 Fluggäste', 'diesem Jahr', 'gleichen Zahl', 'Moritz Frankenberg', 'aller Klimaproteste', 'diesen Herbstferien', 'viele Familien', 'Flughafen Hannover', 'kontroverse Debatten', 'den Abfertigungsschaltern', 'wären nicht Zehntausende Schüler', 'es keine Klimaproteste', 'hannoverschen Schulen', 'zehnten Monat', 'großen Airport-Tafel', 'diesem Vormittag', '„ Die Maschinen', 'Flughafensprecher Sönke Jacobsen den optischen Eindruck', 'den die Schlangen', 'den Check-in-Schaltern', '719 000 Fluggäste', 'diesen Oktober', '„ annähernd dem gleichen Niveau', 'genaue Zahlen', '„ Klimaschutz', 'wichtig –', 'wir dafür Urlaub', 'Karina Schmidt', 'Tochter Aylin', 'Flughafen Hannover', 'Moritz Frankenberg', 'Bewusstseinswandel Herbstferien', 'man dafür Sonne', '„ Klimaschutz', 'den Urlaub', 'ganz ehrlich Karina Schmidt', '35-jährige Physiotherapeutin', 'Tochter Aylin', 'Roten Meer', 'Klimaschutz nicht so wichtig –', '„ Ja', 'Braunschweiger Mutter', 'den 14-', '17-jährigen Kindern Richtung Süden eincheckt', '„ Ich', '365 Tage', '„ ich', 'sehr bewusst Lebensmittel', 'neuesten Handys', 'dieses neuzeitliche Phänomen', 'verständliche Wille', 'den Familienurlaub', 'Diskussionen vermiesen', '„ Ganz', 'ich Blutdruck', 'Raoul Hille', 'diesem Satz', 'Sommer Schlagzeilen', '0,3 Prozent', 'CO2 -Ausstoßes', '3 Prozent', 'Moritz Frankenberg', 'Flug Hannover–Hurghada 1797 Kilogramm CO2', 'durchschnittlichen Flugzeug', 'Der Wert', 'Menge CO2', 'durchschnittliches deutsches Auto', '12 000 Kilometern Fahrleistung', 'ihrem täglichen Radfahren', 'sie sich ihren Flug', 'Ihre Familie', '3594 Kilogramm CO2', 'zwei Familienautos', 'schlaue Leute', 'durchschnittliche Inder', '1600 Kilogramm CO2', 'den Zahlen', '2 Prozent', 'weltweiten CO2-Emissionen ausmacht', 'Côte d´Azur', 'Anna Janßen', '2. v', 'Klimaveränderungen Thema', 'ihrer Familie', 'es ernsthafte Debatten', 'Vater Jörg Janßen', 'Sohn Jonas', '„ Deutschland', 'Mutter Monika', 'Moritz Frankenberg Familienwechsel', '16-jährigen Anna Janßen', 'kommendes Jahr die Jahrgangsfahrt abgeblasen', 'Côte d´Azur', '„ heftige Debatten', 'Mutter Monika Janßen', '„ Wir', 'Flüge teurer', 'Vater Jörg Janßen', '„ Solange Trump seine Klimapolitik', '„ Deutschland', 'Polen „ jeder Haushalt', 'diese Diskussion', 'etliche Male', 'Jörg Janßen', 'ihm die Liebe', 'jeder seine eigenen Argumentationen', 'Rechtfertigungen fürs', 'Familie Janßen', 'westgriechische Patras', 'Hausarzt Karsten Müller', 'Sohn Vincent', 'seinen Kindern', 'Moritz Frankenberg Auch Karsten Müller', 'Insel lasse', '„ Fliegen', '3 Prozent', 'den abgasfreien Tesla', 'Strom fürs Auto', 'hauseigenen Solaranlage', 'Müller sich das billige Argument', '„ Ich', 'wir CO2', 'er Sohn Vincent', 'Hannovers Fluggastzahlen', 'den Herbstferien'])

# %%
blob.parse()
from textblob_de import PatternParser
blob = TextBlob(text, parser=PatternParser(pprint=True, lemmata=True))
blob.parse()
# Out:
#                          WORD   TAG    CHUNK    ROLE   ID     PNP    LEMMA
#
#                       Flydays   FW     -        -      -      -      flydays
#                           for   FW     -        -      -      -      for
#                        Future   FW     -        -      -      -      future
#                           Als   IN     PP       -      -      -      als
#                         hätte   VB     VP       -      -      -      haben
#                            es   PRP    NP       -      -      -      es
#                         keine   JJ     NP ^     -      -      -      kein
#                 Klimaproteste   NN     NP ^     -      -      -      klimaproteste
#                       gegeben   VBN    VP       -      -      -      geben
#                             :   :      -        -      -      -      :
#                     Schlangen   NNS    NP       -      -      -      schlange
#                           von   IN     PP       -      -      PNP    von
#                      Familien   NN     NP       -      -      PNP    familien
#                            am   IN     PP       -      -      PNP    am
#          Abfertigungsschalter   NN     NP       -      -      PNP    abfertigungsschalter
#                            im   IN     PP       -      -      PNP    im
#                     Flughafen   JJ     NP       -      -      PNP    flughaf
#          Hannover-Langenhagen   NN     NP ^     -      -      PNP    hannover-langenhagen
#                             .   .      -        -      -      -      .
#                       719.000   CD     NP       -      -      -      719.000
#                     Fluggäste   NN     NP ^     -      -      -      fluggäste
#                        wurden   VB     VP       -      -      -      werden
#                          hier   RB     ADVP     -      -      -      hier
#                            im   IN     PP       -      -      PNP    im
#                       Oktober   NN     NP       -      -      PNP    oktober
#                          2018   CD     -        -      -      -      2018
#                   abgefertigt   VBN    VP       -      -      -      abfertigen
#                             ,   ,      -        -      -      -      ,
#                            in   IN     PP       -      -      PNP    in
#                        diesem   WDT    NP       -      -      PNP    diesem
#                          Jahr   NN     NP ^     -      -      PNP    jahr
#                       rechnet   NN     NP ^     -      -      PNP    rechnet
#                           der   DT     NP       -      -      PNP    der
#                       Airport   NN     NP ^     -      -      PNP    airport
#                           mit   IN     PP       -      -      PNP    mit
#                           der   DT     NP       -      -      PNP    der
#                      gleichen   JJ     NP ^     -      -      PNP    gleich
#                          Zahl   NN     NP ^     -      -      PNP    zahl
#                             .   .      -        -      -      -      .
#                         fotos   NN     NP       -      -      -      fotos
#                             :   :      -        -      -      -      :
#                        Moritz   NNP    NP       -      -      -      moritz
#                   Frankenberg   NNP    NP ^     -      -      -      frankenberg
#                         Trotz   IN     PP       -      -      PNP    trotz
#                         aller   JJ     NP       -      -      PNP    all
#                 Klimaproteste   NN     NP ^     -      -      PNP    klimaproteste
#                             :   :      -        -      -      -      :
#                            In   IN     PP       -      -      PNP    in
#                        diesen   DT     NP       -      -      PNP    dies
#                  Herbstferien   NN     NP ^     -      -      PNP    herbstferien
#                       fliegen   VB     VP       -      -      -      fliegen
#                       genauso   RB     ADVP     -      -      -      genauso
#                         viele   DT     NP       -      -      -      viel
#                      Familien   NN     NP ^     -      -      -      familien
#                           vom   IN     PP       -      -      PNP    vom
#                     Flughafen   NN     NP       -      -      PNP    flughafen
#                      Hannover   NNP    NP ^     -      -      PNP    hannover
#                            ab   RB     ADVP     -      -      -      ab
#                           wie   IN     PP       -      -      PNP    wie
#                            im   IN     PP ^     -      -      PNP    im
#                       Vorjahr   NN     NP       -      -      PNP    vorjahr
#                             .   .      -        -      -      -      .
#                          Aber   CC     -        -      -      -      aber
#                      vielfach   JJ     NP       -      -      -      vielfach
#                         gehen   PRP$   NP ^     -      -      -      gehen
#                   kontroverse   NN     NP ^     -      -      -      kontroverse
#                      Debatten   NN     NP ^     -      -      -      debatten
#                            im   IN     PP       -      -      PNP    im
#                 Familienkreis   NN     NP       -      -      PNP    familienkreis
#                        voraus   RP     -        -      -      -      voraus
#                             .   .      -        -      -      -      .
#                           Ein   DT     NP       -      -      -      ein
#                        Besuch   NN     NP ^     -      -      -      besuch
#                            in   IN     PP       -      -      PNP    in
#                           der   DT     NP       -      -      PNP    der
#                   Abflugebene   NN     NP ^     -      -      PNP    abflugebene
#                           des   DT     NP       -      -      PNP    des
#                      Airports   NN     NP ^     -      -      PNP    airports
#                             .   .      -        -      -      -      .
#                           Von   IN     PP       -      -      PNP    von
#                        Conrad   NNP    NP       -      -      PNP    conrad
#                           von   IN     PP       -      -      -      von
#                        Meding   FW     -        -      -      -      meding
#                      Hannover   NNP    NP       -      -      -      hannover
#                             .   .      -        -      -      -      .
#                           Die   DT     NP       -      -      -      die
#                     Schlangen   NNS    NP ^     -      -      -      schlange
#                            an   IN     PP       -      -      PNP    an
#                           den   DT     NP       -      -      PNP    den
#         Abfertigungsschaltern   NN     NP ^     -      -      PNP    abfertigungsschaltern
#                          sind   VB     VP       -      -      -      sein
#                            so   RB     ADJP     -      -      -      so
#                          lang   JJ     ADJP ^   -      -      -      lang
#                           wie   IN     PP       -      -      -      wie
#                         immer   RB     ADVP     -      -      -      immer
#                           zum   IN     PP       -      -      PNP    zum
#                 Ferienauftakt   NN     NP       -      -      PNP    ferienauftakt
#                             .   .      -        -      -      -      .
#                           Als   IN     PP       -      -      PNP    als
#                         wären   JJ     NP       -      -      PNP    wär
#                         nicht   RB     NP ^     -      -      PNP    nicht
#                  Zehntausende   JJ     NP ^     -      -      PNP    zehntausend
#                       Schüler   NN     NP ^     -      -      PNP    schüler
#                            in   IN     PP       -      -      PNP    in
#                   Schulstreik   NN     NP       -      -      PNP    schulstreik
#                      getreten   VB     VP       -      -      -      treten
#                             ,   ,      -        -      -      -      ,
#                           als   IN     PP       -      -      -      als
#                         hätte   VB     VP       -      -      -      haben
#                            es   PRP    NP       -      -      -      es
#                         keine   JJ     NP ^     -      -      -      kein
#                 Klimaproteste   NN     NP ^     -      -      -      klimaproteste
#                          auch   RB     ADVP     -      -      -      auch
#                            an   IN     PP       -      -      PNP    an
#                 hannoverschen   JJ     NP       -      -      PNP    hannoversch
#                       Schulen   NN     NP ^     -      -      PNP    schulen
#                       gegeben   VB     VP       -      -      -      geben
#                             –   NN     NP       -      -      -      –
#                      übrigens   RB     ADVP     -      -      -      übrigens
#                         genau   RB     ADVP ^   -      -      -      genau
#                            im   IN     PP       -      -      PNP    im
#                       zehnten   NN     NP       -      -      PNP    zehnten
#                         Monat   NN     NP ^     -      -      PNP    monat
#                         jetzt   VB     VP       -      -      -      jetzen
#                         schon   RP     VP ^     -      -      -      schon
#                             .   .      -        -      -      -      .
#                      Hurghada   NN     NP       -      -      -      hurghada
#                             ,   ,      -        -      -      -      ,
#                      Mallorca   NNP    NP       -      -      -      mallorca
#                             ,   ,      -        -      -      -      ,
#                     Lanzarote   NN     NP       -      -      -      lanzarote
#                             ,   ,      -        -      -      -      ,
#                     Barcelona   NN     NP       -      -      -      barcelona
#                             ,   ,      -        -      -      -      ,
#                     Heraklion   NN     NP       -      -      -      heraklion
#                             ,   ,      -        -      -      -      ,
#                  Thessaloniki   NN     NP       -      -      -      thessaloniki
#                          sind   VB     VP       -      -      -      sein
#                           die   DT     NP       -      -      -      die
#                     Flugziele   NN     NP ^     -      -      -      flugziele
#                           auf   IN     PP       -      -      PNP    auf
#                           der   DT     NP       -      -      PNP    der
#                        großen   JJ     NP ^     -      -      PNP    groß
#                 Airport-Tafel   NN     NP ^     -      -      PNP    airport-tafel
#                            an   IN     PP       -      -      PNP    an
#                        diesem   DT     NP       -      -      PNP    dies
#                     Vormittag   NN     NP ^     -      -      PNP    vormittag
#                             .   .      -        -      -      -      .
#                           Und   CC     -        -      -      -      und
#                      darunter   RB     ADVP     -      -      -      darunter
#                             :   :      -        -      -      -      :
#                      Familien   NN     NP       -      -      -      familien
#                           mit   IN     PP       -      -      PNP    mit
#                  Schulkindern   NN     NP       -      -      PNP    schulkindern
#                             ,   ,      -        -      -      -      ,
#                           die   WDT    NP       -      -      -      die
#                           dem   DT     NP ^     -      -      -      dem
#               Schmuddelwetter   NN     NP ^     -      -      -      schmuddelwetter
#                           gen   IN     PP       -      -      PNP    gen
#                         Süden   NN     NP       -      -      PNP    süden
#                    entfliehen   VB     VP       -      -      -      entfliehen
#                             .   .      -        -      -      -      .
#                           Mit   IN     PP       -      -      PNP    mit
#                           dem   DT     NP       -      -      PNP    dem
#                       Flieger   NN     NP ^     -      -      PNP    flieger
#                             .   .      -        -      -      -      .
#                       Flydays   FW     -        -      -      -      flydays
#                           for   FW     -        -      -      -      for
#                        Future   FW     -        -      -      -      future
#                             ?   .      -        -      -      -      ?
#                          „Die   NN     NP       -      -      -      „die
#                     Maschinen   NNS    NP ^     -      -      -      maschine
#                          sind   VB     VP       -      -      -      sein
#                           gut   JJ     NP       -      -      -      gut
#                       gebucht   NN     NP ^     -      -      -      gebucht
#                             “   "      -        -      -      -      “
#                             ,   ,      -        -      -      -      ,
#                     bestätigt   VB     VP       -      -      -      bestätigen
#             Flughafensprecher   NN     NP       -      -      -      flughafensprecher
#                         Sönke   NN     NP ^     -      -      -      sönke
#                      Jacobsen   NN     NP ^     -      -      -      jacobsen
#                           den   DT     NP ^     -      -      -      den
#                     optischen   JJ     NP ^     -      -      -      optisch
#                      Eindruck   NN     NP ^     -      -      -      eindruck
#                             ,   ,      -        -      -      -      ,
#                           den   WDT    NP       -      -      -      den
#                           die   DT     NP ^     -      -      -      die
#                     Schlangen   NNS    NP ^     -      -      -      schlange
#                            an   IN     PP       -      -      PNP    an
#                           den   DT     NP       -      -      PNP    den
#            Check-in-Schaltern   NN     NP ^     -      -      PNP    check-in-schaltern
#                    vermitteln   VB     VP       -      -      -      vermitteln
#                             .   .      -        -      -      -      .
#                          Etwa   NN     NP       -      -      -      etwa
#                           719   CD     NP ^     -      -      -      719
#                           000   CD     NP ^     -      -      -      000
#                     Fluggäste   NN     NP ^     -      -      -      fluggäste
#                          habe   VB     VP       -      -      -      haben
#                           der   DT     NP       -      -      -      der
#                       Airport   NN     NP ^     -      -      -      airport
#                            im   IN     PP       -      -      PNP    im
#                       Oktober   NN     NP       -      -      PNP    oktober
#                          2018   CD     -        -      -      -      2018
#                       gezählt   RP     -        -      -      -      gezählt
#                             .   .      -        -      -      -      .
#                           Für   IN     PP       -      -      PNP    für
#                        diesen   DT     NP       -      -      PNP    dies
#                       Oktober   NN     NP ^     -      -      PNP    oktober
#                          gehe   NN     NP ^     -      -      PNP    gehe
#                           man   DT     -        -      -      -      man
#                           von   IN     PP       -      -      PNP    von
#                    „annähernd   NN     NP       -      -      PNP    „annähernd
#                           dem   DT     NP ^     -      -      PNP    dem
#                      gleichen   JJ     NP ^     -      -      PNP    gleich
#                        Niveau   NN     NP ^     -      -      PNP    niveau
#                             “   "      -        -      -      -      “
#                           aus   RP     -        -      -      -      aus
#                             ,   ,      -        -      -      -      ,
#                        genaue   JJ     NP       -      -      -      genau
#                        Zahlen   NN     NP ^     -      -      -      zahlen
#                          gibt   VB     VP       -      -      -      geben
#                            es   PRP    NP       -      -      -      es
#                          erst   RB     ADVP     -      -      -      erst
#                            am   IN     PP       -      -      PNP    am
#                    Monatsende   NN     NP       -      -      PNP    monatsende
#                             .   .      -        -      -      -      .
#                  „Klimaschutz   NN     NP       -      -      -      „klimaschutz
#                           ist   VB     VP       -      -      -      sein
#                       wichtig   JJ     NP       -      -      -      wichtig
#                             –   NN     NP ^     -      -      -      –
#                          aber   RB     ADVP     -      -      -      aber
#                         nicht   RB     ADVP ^   -      -      -      nicht
#                            so   RP     -        -      -      -      so
#                             ,   ,      -        -      -      -      ,
#                          dass   IN     PP       -      -      PNP    dass
#                           wir   JJ     NP       -      -      PNP    wir
#                         dafür   RB     NP ^     -      -      PNP    dafür
#                        Urlaub   NN     NP ^     -      -      PNP    urlaub
#                        opfern   VB     VP       -      -      -      opfern
#                             “   "      -        -      -      -      “
#                             :   :      -        -      -      -      :
#                        Karina   NNP    NP       -      -      -      karina
#                       Schmidt   NNP    NP ^     -      -      -      schmidt
#                           mit   IN     PP       -      -      PNP    mit
#                       Tochter   NN     NP       -      -      PNP    tochter
#                         Aylin   NN     NP ^     -      -      PNP    aylin
#                            im   IN     PP       -      -      PNP    im
#                     Flughafen   NN     NP       -      -      PNP    flughafen
#                      Hannover   NNP    NP ^     -      -      PNP    hannover
#                           auf   IN     PP       -      -      PNP    auf
#                           dem   DT     NP       -      -      PNP    dem
#                           Weg   NN     NP ^     -      -      PNP    weg
#                          nach   IN     PP       -      -      PNP    nach
#                      Hurghada   NN     NP       -      -      PNP    hurghada
#                             .   .      -        -      -      -      .
#                        Moritz   NN     NP       -      -      -      moritz
#                   Frankenberg   NNP    NP ^     -      -      -      frankenberg
#                          Also   RB     ADVP     -      -      -      also
#                             :   :      -        -      -      -      :
#                        Nichts   NN     NP       -      -      -      nichts
#                           mit   IN     PP       -      -      -      mit
#                     Flugscham   JJ     ADJP     -      -      -      flugscham
#                             ?   .      -        -      -      -      ?
#                         Macht   NN     NP       -      -      -      macht
#                           der   DT     NP ^     -      -      -      der
#            Bewusstseinswandel   NN     NP ^     -      -      -      bewusstseinswandel
#                  Herbstferien   NN     NP ^     -      -      -      herbstferien
#                             ?   .      -        -      -      -      ?
#                     Erscheint   NN     NP       -      -      -      erscheint
#                           die   DT     NP ^     -      -      -      die
#                    Klimakrise   NN     NP ^     -      -      -      klimakrise
#                       weniger   RB     ADJP     -      -      -      weniger
#                    dramatisch   JJ     ADJP ^   -      -      -      dramatisch
#                             ,   ,      -        -      -      -      ,
#                          wenn   IN     PP       -      -      PNP    wenn
#                           man   DT     NP       -      -      PNP    man
#                         dafür   RB     NP ^     -      -      PNP    dafür
#                         Sonne   NN     NP ^     -      -      PNP    sonne
#                           und   CC     -        -      -      -      und
#                    Sandstrand   NN     NP       -      -      -      sandstrand
#                      aufgeben   VB     VP       -      -      -      aufgeben
#                        müsste   VB     VP ^     -      -      -      müssen
#                             ?   .      -        -      -      -      ?
#                  „Klimaschutz   NN     NP       -      -      -      „klimaschutz
#                           ist   VB     VP       -      -      -      sein
#                       wichtig   JJ     ADJP     -      -      -      wichtig
#                             ,   ,      -        -      -      -      ,
#                          aber   CC     -        -      -      -      aber
#                         nicht   RB     ADVP     -      -      -      nicht
#                            so   RP     -        -      -      -      so
#                             ,   ,      -        -      -      -      ,
#                          dass   IN     PP       -      -      -      dass
#                           wir   JJ     ADJP     -      -      -      wir
#                         dafür   RB     ADVP     -      -      -      dafür
#                           den   DT     NP       -      -      -      den
#                        Urlaub   NN     NP ^     -      -      -      urlaub
#                        opfern   VB     VP       -      -      -      opfern
#                             “   "      -        -      -      -      “
#                             ,   ,      -        -      -      -      ,
#                          sagt   VB     VP       -      -      -      sagen
#                          ganz   RB     NP       -      -      -      ganz
#                       ehrlich   JJ     NP ^     -      -      -      ehrlich
#                        Karina   NNP    NP ^     -      -      -      karina
#                       Schmidt   NNP    NP ^     -      -      -      schmidt
#                             .   .      -        -      -      -      .
#                           Die   DT     NP       -      -      -      die
#                    35-jährige   NN     NP ^     -      -      -      35-jährige
#             Physiotherapeutin   NN     NP ^     -      -      -      physiotherapeutin
#                           ist   VBN    VP       -      -      -      sein
#                           mit   IN     PP       -      -      PNP    mit
#                       Tochter   JJ     NP       -      -      PNP    tocht
#                         Aylin   NN     NP ^     -      -      PNP    aylin
#                             (   (      -        -      -      -      (
#                            15   CD     -        -      -      -      15
#                             )   )      -        -      -      -      )
#                     unterwegs   RB     ADVP     -      -      -      unterwegs
#                          nach   IN     PP       -      -      PNP    nach
#                      Hurghada   NN     NP       -      -      PNP    hurghada
#                             ,   ,      -        -      -      -      ,
#                           das   WDT    -        -      -      -      das
# Sonne-und-Schnorchel-Paradies   RB     ADVP     -      -      -      sonne-und-schnorchel-paradies
#                            am   IN     PP       -      -      PNP    am
#                         Roten   JJ     NP       -      -      PNP    rot
#                          Meer   NN     NP ^     -      -      PNP    meer
#                            in   IN     PP       -      -      PNP    in
#                       Ägypten   NN     NP       -      -      PNP    ägypten
#                             .   .      -        -      -      -      .
#                   Klimaschutz   NN     NP       -      -      -      klimaschutz
#                         nicht   RB     NP ^     -      -      -      nicht
#                            so   RB     NP ^     -      -      -      so
#                       wichtig   JJ     NP ^     -      -      -      wichtig
#                             –   NN     NP ^     -      -      -      –
#                          darf   VB     VP       -      -      -      dürfen
#                           man   DT     -        -      -      -      man
#                            so   RB     ADVP     -      -      -      so
#                         etwas   DT     -        -      -      -      etwas
#                         sagen   VB     VP       -      -      -      sagen
#                            in   IN     PP       -      -      PNP    in
#                        Zeiten   NN     NP       -      -      PNP    zeiten
#                           von   IN     PP       -      -      PNP    von
#                Klimaprotesten   NN     NP       -      -      PNP    klimaprotesten
#                             ?   .      -        -      -      -      ?
#                           „Ja   NN     NP       -      -      -      „ja
#                             ,   ,      -        -      -      -      ,
#                           man   DT     -        -      -      -      man
#                          darf   VB     VP       -      -      -      dürfen
#                             “   "      -        -      -      -      “
#                             ,   ,      -        -      -      -      ,
#                          sagt   VB     VP       -      -      -      sagen
#                          auch   RB     ADVP     -      -      -      auch
#                          eine   DT     NP       -      -      -      ein
#                Braunschweiger   NN     NP ^     -      -      -      braunschweiger
#                        Mutter   NN     NP ^     -      -      -      mutter
#                             ,   ,      -        -      -      -      ,
#                           die   WDT    -        -      -      -      die
#                           mit   IN     PP       -      -      PNP    mit
#                          Mann   NN     NP       -      -      PNP    mann
#                           und   CC     -        -      -      -      und
#                           den   DT     -        -      -      -      den
#                            14   CD     -        -      -      -      14
#                             -   -      -        -      -      -      -
#                           und   CC     -        -      -      -      und
#                   17-jährigen   NN     NP       -      -      -      17-jährigen
#                       Kindern   NN     NP ^     -      -      -      kindern
#                      Richtung   NN     NP ^     -      -      -      richtung
#                         Süden   JJ     NP       -      -      -      süd
#                     eincheckt   NN     NP ^     -      -      -      eincheckt
#                             .   .      -        -      -      -      .
#                          „Ich   NN     NP       -      -      -      „ich
#                         fahre   VB     VP       -      -      -      fahren
#                           365   CD     NP       -      -      -      365
#                          Tage   NN     NP ^     -      -      -      tage
#                            im   IN     PP       -      -      PNP    im
#                          Jahr   NN     NP       -      -      PNP    jahr
#                           mit   IN     PP       -      -      PNP    mit
#                           dem   DT     NP       -      -      PNP    dem
#                           Rad   NN     NP ^     -      -      PNP    rad
#                           zur   IN     PP       -      -      PNP    zur
#                        Arbeit   NN     NP       -      -      PNP    arbeit
#                             “   "      -        -      -      -      “
#                             ,   ,      -        -      -      -      ,
#                          sagt   VB     VP       -      -      -      sagen
#                           sie   PRP    NP       -      -      -      sie
#                             ,   ,      -        -      -      -      ,
#                          „ich   NN     NP       -      -      -      „ich
#                         kaufe   VB     VP       -      -      -      kaufen
#                          sehr   RB     NP       -      -      -      sehr
#                       bewusst   JJ     NP ^     -      -      -      bewusst
#                  Lebensmittel   NN     NP ^     -      -      -      lebensmittel
#                           ein   RP     -        -      -      -      ein
#                             ,   ,      -        -      -      -      ,
#                           ich   PRP    NP       -      -      -      ich
#                         werfe   VB     VP       -      -      -      werfen
#                         davon   RB     ADVP     -      -      -      davon
#                          fast   RB     ADVP ^   -      -      -      fast
#                        nichts   DT     -        -      -      -      nichts
#                           weg   RP     -        -      -      -      weg
#                             ,   ,      -        -      -      -      ,
#                           wir   PRP    NP       -      -      -      wir
#                        kaufen   VB     VP       -      -      -      kaufen
#                         nicht   RB     ADVP     -      -      -      nicht
#                      Unmengen   NN     NP       -      -      -      unmengen
#                            an   IN     PP       -      -      PNP    an
#                     Klamotten   NN     NP       -      -      PNP    klamotten
#                             ,   ,      -        -      -      -      ,
#                           und   CC     -        -      -      -      und
#                           die   DT     NP       -      -      -      die
#                        Kinder   NN     NP ^     -      -      -      kinder
#                         haben   VB     VP       -      -      -      haben
#                         nicht   RB     ADVP     -      -      -      nicht
#                       ständig   RB     ADVP ^   -      -      -      ständig
#                           die   DT     NP       -      -      -      die
#                      neuesten   JJ     NP ^     -      -      -      neuest
#                        Handys   NN     NP ^     -      -      -      handys
#                             .   .      -        -      -      -      .
#                           Ich   PRP    NP       -      -      -      ich
#                         lasse   VB     VP       -      -      -      lassen
#                           mir   PRP    NP       -      -      -      mir
#                         nicht   RB     VP       -      -      -      nicht
#                  unterstellen   VB     VP ^     -      -      -      unterstellen
#                             ,   ,      -        -      -      -      ,
#                           ich   PRP    NP       -      -      -      ich
#                           sei   VB     VP       -      -      -      sein
#                         nicht   RB     ADVP     -      -      -      nicht
#                 umweltbewusst   NN     NP       -      -      -      umweltbewusst
#                             .   .      -        -      -      -      .
#                             “   "      -        -      -      -      “
#                        Allein   NN     NP       -      -      -      allein
#                           der   DT     NP ^     -      -      -      der
#                         Drang   NN     NP ^     -      -      -      drang
#                           zur   IN     PP       -      -      PNP    zur
#                Rechtfertigung   NN     NP       -      -      PNP    rechtfertigung
#                         zeigt   VB     VP       -      -      -      zeigen
#                             :   :      -        -      -      -      :
#                            Da   RB     VP       -      -      -      da
#                           ist   VB     VP ^     -      -      -      sein
#                      durchaus   RB     ADJP     -      -      -      durchaus
#                     Flugscham   JJ     ADJP ^   -      -      -      flugscham
#                             ,   ,      -        -      -      -      ,
#                        dieses   WDT    NP       -      -      -      dieses
#                  neuzeitliche   JJ     NP ^     -      -      -      neuzeitlich
#                      Phänomen   NN     NP ^     -      -      -      phänomen
#                             ,   ,      -        -      -      -      ,
#                          aber   CC     -        -      -      -      aber
#                      zugleich   RB     ADVP     -      -      -      zugleich
#                           der   DT     NP       -      -      -      der
#                 verständliche   JJ     NP ^     -      -      -      verständlich
#                         Wille   NN     NP ^     -      -      -      wille
#                             ,   ,      -        -      -      -      ,
#                          sich   PRP    NP       -      -      -      sich
#                    wenigstens   RB     ADVP     -      -      -      wenigstens
#                           den   DT     NP       -      -      -      den
#                Familienurlaub   NN     NP ^     -      -      -      familienurlaub
#                         nicht   RB     ADVP     -      -      -      nicht
#                          auch   RB     ADVP ^   -      -      -      auch
#                          noch   RB     ADVP ^   -      -      -      noch
#                           von   IN     PP       -      -      PNP    von
#                  Diskussionen   NN     NP       -      -      PNP    diskussionen
#                     vermiesen   NN     NP ^     -      -      PNP    vermiesen
#                            zu   IN     PP       -      -      -      zu
#                        lassen   VB     VP       -      -      -      lassen
#                             .   .      -        -      -      -      .
#                         „Ganz   NN     NP       -      -      -      „ganz
#                       ehrlich   JJ     ADJP     -      -      -      ehrlich
#                             :   :      -        -      -      -      :
#                          Wenn   IN     PP       -      -      -      wenn
#                           ich   JJ     ADJP     -      -      -      ich
#                           das   DT     NP       -      -      -      das
# ...
#                             :   :      -        -      -      -      :
#                      „Fliegen   NN     NP       -      -      -      „fliegen
#                         macht   VB     VP       -      -      -      machen
#                             2   CD     -        -      -      -      2
#                           bis   IN     PP       -      -      PNP    bis
#                             3   CD     NP       -      -      PNP    3
#                       Prozent   NN     NP ^     -      -      PNP    prozent
#                           des   DT     NP       -      -      PNP    des
#                 CO2-Ausstoßes   NN     NP ^     -      -      PNP    co2-ausstoßes
#                           aus   RP     -        -      -      -      aus
#                             .   .      -        -      -      -      .
#                             “   "      -        -      -      -      “
#                            Er   PRP    NP       -      -      -      er
#                           ist   VB     VP       -      -      -      sein
#                      Hautarzt   NN     NP       -      -      -      hautarzt
#                             ,   ,      -        -      -      -      ,
#                           hat   VB     VP       -      -      -      haben
#                          viel   RB     ADVP     -      -      -      viel
#                          auch   RB     ADVP ^   -      -      -      auch
#                           mit   IN     PP       -      -      PNP    mit
#          Atemwegserkrankungen   NN     NP       -      -      PNP    atemwegserkrankungen
#                            zu   TO     VP       -      -      -      zu
#                           tun   VB     VP ^     -      -      -      tun
#                             .   .      -        -      -      -      .
#                       Deshalb   RB     ADVP     -      -      -      deshalb
#                           hat   RB     ADVP     -      -      -      hat
#                            er   PRP    NP       -      -      -      er
#                     gehandelt   VB     VP       -      -      -      handeln
#                           und   CC     -        -      -      -      und
#                      versucht   RB     ADVP     -      -      -      versucht
#                             ,   ,      -        -      -      -      ,
#                           die   DT     NP       -      -      -      die
#                          Welt   NN     NP ^     -      -      -      welt
#                         etwas   DT     -        -      -      -      etwas
#                        besser   RB     VP       -      -      -      besser
#                            zu   TO     VP ^     -      -      -      zu
#                        machen   VB     VP ^     -      -      -      machen
#                             .   .      -        -      -      -      .
#                            Er   PRP    NP       -      -      -      er
#                         fährt   VB     VP       -      -      -      fahren
#                           den   DT     NP       -      -      -      den
#                   abgasfreien   NN     NP ^     -      -      -      abgasfreien
#                         Tesla   NN     NP ^     -      -      -      tesla
#                             ,   ,      -        -      -      -      ,
#                           mit   IN     PP       -      -      PNP    mit
#                           dem   WDT    NP       -      -      PNP    dem
#                           die   DT     NP ^     -      -      PNP    die
#                       Familie   NN     NP ^     -      -      PNP    familie
#                          auch   RB     ADVP     -      -      -      auch
#                           zum   IN     PP       -      -      PNP    zum
#                     Flughafen   NN     NP       -      -      PNP    flughafen
#                      gekommen   VBN    VP       -      -      PNP    kommen
#                           ist   VB     VP ^     -      -      PNP    sein
#                             .   .      -        -      -      -      .
#                           Der   DT     NP       -      -      -      der
#                         Strom   NN     NP ^     -      -      -      strom
#                          fürs   NN     NP ^     -      -      -      fürs
#                          Auto   NN     NP ^     -      -      -      auto
#                         kommt   VB     VP       -      -      -      kommen
#                           aus   IN     PP       -      -      PNP    aus
#                           der   DT     NP       -      -      PNP    der
#                   hauseigenen   NN     NP ^     -      -      PNP    hauseigenen
#                   Solaranlage   NN     NP ^     -      -      PNP    solaranlage
#                             ,   ,      -        -      -      -      ,
#                        sodass   CC     -        -      -      -      sodass
#                        Müller   NN     NP       -      -      -      müller
#                          sich   PRP    NP ^     -      -      -      sich
#                           das   DT     NP       -      -      -      das
#                       billige   JJ     NP ^     -      -      -      billig
#                      Argument   NN     NP ^     -      -      -      argument
#                         nicht   RB     VP       -      -      -      nicht
#                       ständig   RB     VP ^     -      -      -      ständig
#                       anhören   VB     VP ^     -      -      -      anhören
#                          muss   VB     VP ^     -      -      -      müssen
#                             ,   ,      -        -      -      -      ,
#                          sein   PRP$   NP       -      -      -      sein
#                          Auto   NN     NP ^     -      -      -      auto
#                         fahre   VBN    VP       -      -      -      fahren
#                            ja   RB     ADVP     -      -      -      ja
#                           mit   IN     PP       -      -      PNP    mit
#                         einem   DT     NP       -      -      PNP    ein
#                      Strommix   NN     NP ^     -      -      PNP    strommix
#                             ,   ,      -        -      -      -      ,
#                           der   DT     NP       -      -      -      der
#              Braunkohleabgase   NN     NP ^     -      -      -      braunkohleabgase
#                    beinhaltet   VB     VP       -      -      -      beinhalten
#                             .   .      -        -      -      -      .
#                          „Ich   NN     NP       -      -      -      „ich
#                          habe   VB     VP       -      -      -      haben
#                           mit   TO     -        -      -      -      mit
#                        meinen   PRP$   NP       -      -      -      meinen
#                       Kindern   NN     NP ^     -      -      -      kindern
#                    besprochen   VB     VP       -      -      -      besprechen
#                             ,   ,      -        -      -      -      ,
#                           wie   IN     PP       -      -      PNP    wie
#                           wir   JJ     NP       -      -      PNP    wir
#                           CO2   NN     NP ^     -      -      PNP    co2
#                        sparen   VB     VP       -      -      -      sparen
#                        können   VB     VP ^     -      -      -      können
#                           und   CC     -        -      -      -      und
#                           was   WP     -        -      -      -      was
#                      sinnvoll   JJ     ADJP     -      -      -      sinnvoll
#                           ist   VB     VP       -      -      -      sein
#                             “   "      -        -      -      -      “
#                             ,   ,      -        -      -      -      ,
#                          sagt   VB     VP       -      -      -      sagen
#                            er   PRP    NP       -      -      -      er
#                             ,   ,      -        -      -      -      ,
#                           als   IN     PP       -      -      PNP    als
#                            er   PRP    NP       -      -      PNP    er
#                          Sohn   NN     NP ^     -      -      PNP    sohn
#                       Vincent   NNP    NP ^     -      -      PNP    vincent
#                             (   (      -        -      -      -      (
#                            10   CD     -        -      -      -      10
#                             )   )      -        -      -      -      )
#                            an   IN     PP       -      -      PNP    an
#                          sich   PRP    NP       -      -      PNP    sich
#                        drückt   NN     NP ^     -      -      PNP    drückt
#                             .   .      -        -      -      -      .
#                          Dann   RB     VP       -      -      -      dann
#                          geht   VB     VP ^     -      -      -      gehen
#                            es   PRP    NP       -      -      -      es
#                          nach   IN     PP       -      -      PNP    nach
#                     Lanzarote   NN     NP       -      -      PNP    lanzarote
#                             .   .      -        -      -      -      .
#                           Man   DT     -        -      -      -      man
#                          kann   VB     VP       -      -      -      können
#                    vielleicht   RB     VP ^     -      -      -      vielleicht
#                         sagen   VB     VP ^     -      -      -      sagen
#                             :   :      -        -      -      -      :
#                     Hannovers   NN     NP       -      -      -      hannovers
#                Fluggastzahlen   NN     NP ^     -      -      -      fluggastzahlen
#                          sind   VB     VP       -      -      -      sein
#                          noch   RB     ADJP     -      -      -      noch
#                         nicht   RB     ADJP ^   -      -      -      nicht
#                   signifikant   JJ     ADJP ^   -      -      -      signifikant
#                zurückgegangen   JJ     ADJP ^   -      -      -      zurückgegang
#                            in   IN     PP       -      -      PNP    in
#                           den   DT     NP       -      -      PNP    den
#                  Herbstferien   NN     NP ^     -      -      PNP    herbstferien
#                          2019   CD     -        -      -      -      2019
#                             .   .      -        -      -      -      .
#                          Aber   CC     -        -      -      -      aber
#                           die   DT     NP       -      -      -      die
#                  Diskussionen   NN     NP ^     -      -      -      diskussionen
#                         haben   RB     ADVP     -      -      -      haben
#                    zugenommen   RP     -        -      -      -      zugenommen
#                             .   .      -        -      -      -      .
#                           Und   CC     -        -      -      -      und
#                           das   DT     -        -      -      -      das
#                           ist   VB     VP       -      -      -      sein
#                    vielleicht   RB     ADVP     -      -      -      vielleicht
#                         schon   RB     ADVP ^   -      -      -      schon
#                           mal   RB     ADVP ^   -      -      -      mal
#                           ein   DT     NP       -      -      -      ein
#                        Anfang   NN     NP ^     -      -      -      anfang
#                             .   .      -        -      -      -      .

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.12025641025641025, subjectivity=0.055384615384615386)

# %%
help(blob)
# Out:
# Help on TextBlobDE in module textblob_de.blob object:
#
# class TextBlobDE(BaseBlob)
#  |  ``TextBlob`` class initialised with German default models:
#  |
#  |  :param str text: A string.
#  |  :param tokenizer: (optional) A tokenizer instance. If ``None``, defaults to
#  |      :class:`NLTKPunktTokenizer() <textblob_de.tokenizers.NLTKPunktTokenizer>`.
#  |  :param np_extractor: (optional) An NPExtractor instance. If ``None``,
#  |      defaults to :class:`PatternParserNPExtractor()
#  |      <textblob_de.np_extractors.PatternParserNPExtractor>`.
#  |  :param pos_tagger: (optional) A Tagger instance. If ``None``, defaults to
#  |      :class:`PatternTagger <textblob_de.taggers.PatternTagger>`.
#  |  :param analyzer: (optional) A sentiment analyzer. If ``None``, defaults to
#  |      :class:`PatternAnalyzer <textblob_de.sentiments.PatternAnalyzer>`.
#  |  :param classifier: (optional) A classifier.
#  |
#  |  Method resolution order:
#  |      TextBlobDE
#  |      BaseBlob
#  |      textblob.blob.BaseBlob
#  |      textblob.mixins.StringlikeMixin
#  |      textblob.mixins.BlobComparableMixin
#  |      textblob.mixins.ComparableMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  polarity = <textblob.decorators.cached_property object>
#  |  sentences = <textblob.decorators.cached_property object>
#  |  sentiment = <textblob.decorators.cached_property object>
#  |  sentiment_assessments = <textblob.decorators.cached_property object>
#  |  subjectivity = <textblob.decorators.cached_property object>
#  |  to_json(self, *args, **kwargs)
#  |      Return a json representation (str) of this blob. Takes the same
#  |      arguments as json.dumps.
#  |
#  |      .. versionadded:: 0.5.1 (``textblob``)
#  |
#  |  words = <textblob.decorators.cached_property object>
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  json
#  |      The json representation of this blob.
#  |
#  |      .. versionchanged:: 0.5.1
#  |          Made ``json`` a property instead of a method to restore backwards
#  |          compatibility that was broken after version 0.4.0.
#  |
#  |  raw_sentences
#  |      List of strings, the raw sentences in the blob.
#  |
#  |  serialized
#  |      Returns a list of each sentence's dict representation.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseBlob:
#  |
#  |  __add__(self, other)
#  |      Concatenates two text objects the same way Python strings are
#  |      concatenated.
#  |
#  |      Arguments:
#  |      - `other`: a string or a text object
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __init__(self, text, tokenizer=None, pos_tagger=None, np_extractor=None, analyzer=None, parser=None, classifier=None, clean_html=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  correct(self)
#  |      Attempt to correct the spelling of a blob.
#  |
#  |      .. versionadded:: 0.6.0 (``textblob``)
#  |
#  |      :rtype: :class:`BaseBlob <BaseBlob>`
#  |
#  |  noun_phrases = <textblob.decorators.cached_property object>
#  |  np_counts = <textblob.decorators.cached_property object>
#  |  pos_tags = <textblob.decorators.cached_property object>
#  |  split(self, sep=None, maxsplit=9223372036854775807)
#  |      Behaves like the built-in str.split() except returns a
#  |      WordList.
#  |
#  |      :rtype: :class:`WordList <WordList>`
#  |
#  |  tags = <textblob.decorators.cached_property object>
#  |  tokenize(self, tokenizer=None)
#  |      Return a list of tokens, using ``tokenizer``.
#  |
#  |      :param tokenizer: (optional) A tokenizer object. If None, defaults to
#  |          this blob's default tokenizer.
#  |
#  |  tokens = <textblob.decorators.cached_property object>
#  |  translate(self, from_lang=None, to='de')
#  |      Translate the blob to another language.
#  |
#  |  word_counts = <textblob.decorators.cached_property object>
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from textblob.blob.BaseBlob:
#  |
#  |  classify(self)
#  |      Classify the blob using the blob's ``classifier``.
#  |
#  |  detect_language(self)
#  |      Detect the blob's language using the Google Translate API.
#  |
#  |      Requires an internet connection.
#  |
#  |      Usage:
#  |      ::
#  |
#  |          >>> b = TextBlob("bonjour")
#  |          >>> b.detect_language()
#  |          u'fr'
#  |
#  |      Language code reference:
#  |          https://developers.google.com/translate/v2/using_rest#language-params
#  |
#  |      .. versionadded:: 0.5.0
#  |
#  |      :rtype: str
#  |
#  |  ngrams(self, n=3)
#  |      Return a list of n-grams (tuples of n successive words) for this
#  |      blob.
#  |
#  |      :rtype: List of :class:`WordLists <WordList>`
#  |
#  |  parse(self, parser=None)
#  |      Parse the text.
#  |
#  |      :param parser: (optional) A parser instance. If ``None``, defaults to
#  |          this blob's default parser.
#  |
#  |      .. versionadded:: 0.6.0
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from textblob.blob.BaseBlob:
#  |
#  |  analyzer = <textblob.en.sentiments.PatternAnalyzer object>
#  |
#  |  np_extractor = <textblob.en.np_extractors.FastNPExtractor object>
#  |
#  |  parser = <textblob.en.parsers.PatternParser object>
#  |
#  |  pos_tagger = <textblob.en.taggers.NLTKTagger object>
#  |
#  |  tokenizer = <textblob.tokenizers.WordTokenizer object>
#  |
#  |  translator = <textblob.translate.Translator object>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from textblob.mixins.StringlikeMixin:
#  |
#  |  __contains__(self, sub)
#  |      Implements the `in` keyword like a Python string.
#  |
#  |  __getitem__(self, index)
#  |      Returns a  substring. If index is an integer, returns a Python
#  |      string of a single character. If a range is given, e.g. `blob[3:5]`,
#  |      a new instance of the class is returned.
#  |
#  |  __iter__(self)
#  |      Makes the object iterable as if it were a string,
#  |      iterating through the raw string's characters.
#  |
#  |  __len__(self)
#  |      Returns the length of the raw text.
#  |
#  |  __repr__(self)
#  |      Returns a string representation for debugging.
#  |
#  |  __str__(self)
#  |      Returns a string representation used in print statements
#  |      or str(my_blob).
#  |
#  |  ends_with = endswith(self, suffix, start=0, end=9223372036854775807)
#  |      Returns True if the blob ends with the given suffix.
#  |
#  |  endswith(self, suffix, start=0, end=9223372036854775807)
#  |      Returns True if the blob ends with the given suffix.
#  |
#  |  find(self, sub, start=0, end=9223372036854775807)
#  |      Behaves like the built-in str.find() method. Returns an integer,
#  |      the index of the first occurrence of the substring argument sub in the
#  |      sub-string given by [start:end].
#  |
#  |  format(self, *args, **kwargs)
#  |      Perform a string formatting operation, like the built-in
#  |      `str.format(*args, **kwargs)`. Returns a blob object.
#  |
#  |  index(self, sub, start=0, end=9223372036854775807)
#  |      Like blob.find() but raise ValueError when the substring
#  |      is not found.
#  |
#  |  join(self, iterable)
#  |      Behaves like the built-in `str.join(iterable)` method, except
#  |      returns a blob object.
#  |
#  |      Returns a blob which is the concatenation of the strings or blobs
#  |      in the iterable.
#  |
#  |  lower(self)
#  |      Like str.lower(), returns new object with all lower-cased characters.
#  |
#  |  replace(self, old, new, count=9223372036854775807)
#  |      Return a new blob object with all the occurence of `old` replaced
#  |      by `new`.
#  |
#  |  rfind(self, sub, start=0, end=9223372036854775807)
#  |      Behaves like the built-in str.rfind() method. Returns an integer,
#  |      the index of he last (right-most) occurence of the substring argument
#  |      sub in the sub-sequence given by [start:end].
#  |
#  |  rindex(self, sub, start=0, end=9223372036854775807)
#  |      Like blob.rfind() but raise ValueError when substring is not
#  |      found.
#  |
#  |  starts_with = startswith(self, prefix, start=0, end=9223372036854775807)
#  |      Returns True if the blob starts with the given prefix.
#  |
#  |  startswith(self, prefix, start=0, end=9223372036854775807)
#  |      Returns True if the blob starts with the given prefix.
#  |
#  |  strip(self, chars=None)
#  |      Behaves like the built-in str.strip([chars]) method. Returns
#  |      an object with leading and trailing whitespace removed.
#  |
#  |  title(self)
#  |      Returns a blob object with the text in title-case.
#  |
#  |  upper(self)
#  |      Like str.upper(), returns new object with all upper-cased characters.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from textblob.mixins.StringlikeMixin:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from textblob.mixins.ComparableMixin:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __ge__(self, other)
#  |      Return self>=value.
#  |
#  |  __gt__(self, other)
#  |      Return self>value.
#  |
#  |  __le__(self, other)
#  |      Return self<=value.
#  |
#  |  __lt__(self, other)
#  |      Return self<value.
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.

# %%
blob.pos_tags
# Out:
# [('Flydays', 'FW'),
#  ('for', 'FW'),
#  ('Future', 'FW'),
#  ('Als', 'IN'),
#  ('hätte', 'VB'),
#  ('es', 'PRP'),
#  ('keine', 'JJ'),
#  ('Klimaproteste', 'NN'),
#  ('gegeben', 'VBN'),
#  ('Schlangen', 'NNS'),
#  ('von', 'IN'),
#  ('Familien', 'NN'),
#  ('am', 'IN'),
#  ('Abfertigungsschalter', 'NN'),
#  ('im', 'IN'),
#  ('Flughafen', 'JJ'),
#  ('Hannover-Langenhagen', 'NN'),
#  ('719.000', 'CD'),
#  ('Fluggäste', 'NN'),
#  ('wurden', 'VB'),
#  ('hier', 'RB'),
#  ('im', 'IN'),
#  ('Oktober', 'NN'),
#  ('2018', 'CD'),
#  ('abgefertigt', 'VBN'),
#  ('in', 'IN'),
#  ('diesem', 'WDT'),
#  ('Jahr', 'NN'),
#  ('rechnet', 'NN'),
#  ('der', 'DT'),
#  ('Airport', 'NN'),
#  ('mit', 'IN'),
#  ('der', 'DT'),
#  ('gleichen', 'JJ'),
#  ('Zahl', 'NN'),
#  ('fotos', 'NN'),
#  ('Moritz', 'NNP'),
#  ('Frankenberg', 'NNP'),
#  ('Trotz', 'IN'),
#  ('aller', 'JJ'),
#  ('Klimaproteste', 'NN'),
#  ('In', 'IN'),
#  ('diesen', 'DT'),
#  ('Herbstferien', 'NN'),
#  ('fliegen', 'VB'),
#  ('genauso', 'RB'),
#  ('viele', 'DT'),
#  ('Familien', 'NN'),
#  ('vom', 'IN'),
#  ('Flughafen', 'NN'),
#  ('Hannover', 'NNP'),
#  ('ab', 'RB'),
#  ('wie', 'IN'),
#  ('im', 'IN'),
#  ('Vorjahr', 'NN'),
#  ('Aber', 'CC'),
#  ('vielfach', 'JJ'),
#  ('gehen', 'PRP$'),
#  ('kontroverse', 'NN'),
#  ('Debatten', 'NN'),
#  ('im', 'IN'),
#  ('Familienkreis', 'NN'),
#  ('voraus', 'RP'),
#  ('Ein', 'DT'),
#  ('Besuch', 'NN'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Abflugebene', 'NN'),
#  ('des', 'DT'),
#  ('Airports', 'NN'),
#  ('Von', 'IN'),
#  ('Conrad', 'NNP'),
#  ('von', 'IN'),
#  ('Meding', 'FW'),
#  ('Hannover', 'NNP'),
#  ('Die', 'DT'),
#  ('Schlangen', 'NNS'),
#  ('an', 'IN'),
#  ('den', 'DT'),
#  ('Abfertigungsschaltern', 'NN'),
#  ('sind', 'VB'),
#  ('so', 'RB'),
#  ('lang', 'JJ'),
#  ('wie', 'IN'),
#  ('immer', 'RB'),
#  ('zum', 'IN'),
#  ('Ferienauftakt', 'NN'),
#  ('Als', 'IN'),
#  ('wären', 'JJ'),
#  ('nicht', 'RB'),
#  ('Zehntausende', 'JJ'),
#  ('Schüler', 'NN'),
#  ('in', 'IN'),
#  ('Schulstreik', 'NN'),
#  ('getreten', 'VB'),
#  ('als', 'IN'),
#  ('hätte', 'VB'),
#  ('es', 'PRP'),
#  ('keine', 'JJ'),
#  ('Klimaproteste', 'NN'),
#  ('auch', 'RB'),
#  ('an', 'IN'),
#  ('hannoverschen', 'JJ'),
#  ('Schulen', 'NN'),
#  ('gegeben', 'VB'),
#  ('–', 'NN'),
#  ('übrigens', 'RB'),
#  ('genau', 'RB'),
#  ('im', 'IN'),
#  ('zehnten', 'NN'),
#  ('Monat', 'NN'),
#  ('jetzt', 'VB'),
#  ('schon', 'RP'),
#  ('Hurghada', 'NN'),
#  ('Mallorca', 'NNP'),
#  ('Lanzarote', 'NN'),
#  ('Barcelona', 'NN'),
#  ('Heraklion', 'NN'),
#  ('Thessaloniki', 'NN'),
#  ('sind', 'VB'),
#  ('die', 'DT'),
#  ('Flugziele', 'NN'),
#  ('auf', 'IN'),
#  ('der', 'DT'),
#  ('großen', 'JJ'),
#  ('Airport-Tafel', 'NN'),
#  ('an', 'IN'),
#  ('diesem', 'DT'),
#  ('Vormittag', 'NN'),
#  ('Und', 'CC'),
#  ('darunter', 'RB'),
#  ('Familien', 'NN'),
#  ('mit', 'IN'),
#  ('Schulkindern', 'NN'),
#  ('die', 'WDT'),
#  ('dem', 'DT'),
#  ('Schmuddelwetter', 'NN'),
#  ('gen', 'IN'),
#  ('Süden', 'NN'),
#  ('entfliehen', 'VB'),
#  ('Mit', 'IN'),
#  ('dem', 'DT'),
#  ('Flieger', 'NN'),
#  ('Flydays', 'FW'),
#  ('for', 'FW'),
#  ('Future', 'FW'),
#  ('„', 'NN'),
#  ('Die', 'DT'),
#  ('Maschinen', 'NNS'),
#  ('sind', 'VB'),
#  ('gut', 'JJ'),
#  ('gebucht', 'NN'),
#  ('bestätigt', 'VB'),
#  ('Flughafensprecher', 'NN'),
#  ('Sönke', 'NN'),
#  ('Jacobsen', 'NN'),
#  ('den', 'DT'),
#  ('optischen', 'JJ'),
#  ('Eindruck', 'NN'),
#  ('den', 'WDT'),
#  ('die', 'DT'),
#  ('Schlangen', 'NNS'),
#  ('an', 'IN'),
#  ('den', 'DT'),
#  ('Check-in-Schaltern', 'NN'),
#  ('vermitteln', 'VB'),
#  ('Etwa', 'NN'),
#  ('719', 'CD'),
#  ('000', 'CD'),
#  ('Fluggäste', 'NN'),
#  ('habe', 'VB'),
#  ('der', 'DT'),
#  ('Airport', 'NN'),
#  ('im', 'IN'),
#  ('Oktober', 'NN'),
#  ('2018', 'CD'),
#  ('gezählt', 'RP'),
#  ('Für', 'IN'),
#  ('diesen', 'DT'),
#  ('Oktober', 'NN'),
#  ('gehe', 'NN'),
#  ('man', 'DT'),
#  ('von', 'IN'),
#  ('„', 'NN'),
#  ('annähernd', 'NN'),
#  ('dem', 'DT'),
#  ('gleichen', 'JJ'),
#  ('Niveau', 'NN'),
#  ('aus', 'RP'),
#  ('genaue', 'JJ'),
#  ('Zahlen', 'NN'),
#  ('gibt', 'VB'),
#  ('es', 'PRP'),
#  ('erst', 'RB'),
#  ('am', 'IN'),
#  ('Monatsende', 'NN'),
#  ('„', 'NN'),
#  ('Klimaschutz', 'NN'),
#  ('ist', 'VB'),
#  ('wichtig', 'JJ'),
#  ('–', 'NN'),
#  ('aber', 'RB'),
#  ('nicht', 'RB'),
#  ('so', 'RP'),
#  ('dass', 'IN'),
#  ('wir', 'JJ'),
#  ('dafür', 'RB'),
#  ('Urlaub', 'NN'),
#  ('opfern', 'VB'),
#  ('Karina', 'NNP'),
#  ('Schmidt', 'NNP'),
#  ('mit', 'IN'),
#  ('Tochter', 'NN'),
#  ('Aylin', 'NN'),
#  ('im', 'IN'),
#  ('Flughafen', 'NN'),
#  ('Hannover', 'NNP'),
#  ('auf', 'IN'),
#  ('dem', 'DT'),
#  ('Weg', 'NN'),
#  ('nach', 'IN'),
#  ('Hurghada', 'NN'),
#  ('Moritz', 'NN'),
#  ('Frankenberg', 'NNP'),
#  ('Also', 'RB'),
#  ('Nichts', 'NN'),
#  ('mit', 'IN'),
#  ('Flugscham', 'JJ'),
#  ('Macht', 'NN'),
#  ('der', 'DT'),
#  ('Bewusstseinswandel', 'NN'),
#  ('Herbstferien', 'NN'),
#  ('Erscheint', 'NN'),
#  ('die', 'DT'),
#  ('Klimakrise', 'NN'),
#  ('weniger', 'RB'),
#  ('dramatisch', 'JJ'),
#  ('wenn', 'IN'),
#  ('man', 'DT'),
#  ('dafür', 'RB'),
#  ('Sonne', 'NN'),
#  ('und', 'CC'),
#  ('Sandstrand', 'NN'),
#  ('aufgeben', 'VB'),
#  ('müsste', 'VB'),
#  ('„', 'NN'),
#  ('Klimaschutz', 'NN'),
#  ('ist', 'VB'),
#  ('wichtig', 'JJ'),
#  ('aber', 'CC'),
#  ('nicht', 'RB'),
#  ('so', 'RP'),
#  ('dass', 'IN'),
#  ('wir', 'JJ'),
#  ('dafür', 'RB'),
#  ('den', 'DT'),
#  ('Urlaub', 'NN'),
#  ('opfern', 'VB'),
#  ('sagt', 'VB'),
#  ('ganz', 'RB'),
#  ('ehrlich', 'JJ'),
#  ('Karina', 'NNP'),
#  ('Schmidt', 'NNP'),
#  ('Die', 'DT'),
#  ('35-jährige', 'NN'),
#  ('Physiotherapeutin', 'NN'),
#  ('ist', 'VBN'),
#  ('mit', 'IN'),
#  ('Tochter', 'JJ'),
#  ('Aylin', 'NN'),
#  ('15', 'CD'),
#  ('unterwegs', 'RB'),
#  ('nach', 'IN'),
#  ('Hurghada', 'NN'),
#  ('das', 'WDT'),
#  ('Sonne-und-Schnorchel-Paradies', 'RB'),
#  ('am', 'IN'),
#  ('Roten', 'JJ'),
#  ('Meer', 'NN'),
#  ('in', 'IN'),
#  ('Ägypten', 'NN'),
#  ('Klimaschutz', 'NN'),
#  ('nicht', 'RB'),
#  ('so', 'RB'),
#  ('wichtig', 'JJ'),
#  ('–', 'NN'),
#  ('darf', 'VB'),
#  ('man', 'DT'),
#  ('so', 'RB'),
#  ('etwas', 'DT'),
#  ('sagen', 'VB'),
#  ('in', 'IN'),
#  ('Zeiten', 'NN'),
#  ('von', 'IN'),
#  ('Klimaprotesten', 'NN'),
#  ('„', 'NN'),
#  ('Ja', 'NN'),
#  ('man', 'DT'),
#  ('darf', 'VB'),
#  ('sagt', 'VB'),
#  ('auch', 'RB'),
#  ('eine', 'DT'),
#  ('Braunschweiger', 'NN'),
#  ('Mutter', 'NN'),
#  ('die', 'WDT'),
#  ('mit', 'IN'),
#  ('Mann', 'NN'),
#  ('und', 'CC'),
#  ('den', 'DT'),
#  ('14-', 'CD'),
#  ('und', 'CC'),
#  ('17-jährigen', 'NN'),
#  ('Kindern', 'NN'),
#  ('Richtung', 'NN'),
#  ('Süden', 'JJ'),
#  ('eincheckt', 'NN'),
#  ('„', 'NN'),
#  ('Ich', 'PRP'),
#  ('fahre', 'VB'),
#  ('365', 'CD'),
#  ('Tage', 'NN'),
#  ('im', 'IN'),
#  ('Jahr', 'NN'),
#  ('mit', 'IN'),
#  ('dem', 'DT'),
#  ('Rad', 'NN'),
#  ('zur', 'IN'),
#  ('Arbeit', 'NN'),
#  ('sagt', 'VB'),
#  ('sie', 'PRP'),
#  ('„', 'NN'),
#  ('ich', 'PRP'),
#  ('kaufe', 'VB'),
#  ('sehr', 'RB'),
#  ('bewusst', 'JJ'),
#  ('Lebensmittel', 'NN'),
#  ('ein', 'RP'),
#  ('ich', 'PRP'),
#  ('werfe', 'VB'),
#  ('davon', 'RB'),
#  ('fast', 'RB'),
#  ('nichts', 'DT'),
#  ('weg', 'RP'),
#  ('wir', 'PRP'),
#  ('kaufen', 'VB'),
#  ('nicht', 'RB'),
#  ('Unmengen', 'NN'),
#  ('an', 'IN'),
#  ('Klamotten', 'NN'),
#  ('und', 'CC'),
#  ('die', 'DT'),
#  ('Kinder', 'NN'),
#  ('haben', 'VB'),
#  ('nicht', 'RB'),
#  ('ständig', 'RB'),
#  ('die', 'DT'),
#  ('neuesten', 'JJ'),
#  ('Handys', 'NN'),
#  ('Ich', 'PRP'),
#  ('lasse', 'VB'),
#  ('mir', 'PRP'),
#  ('nicht', 'RB'),
#  ('unterstellen', 'VB'),
#  ('ich', 'PRP'),
#  ('sei', 'VB'),
#  ('nicht', 'RB'),
#  ('umweltbewusst.', 'JJ'),
#  ('Allein', 'NN'),
#  ('der', 'DT'),
#  ('Drang', 'NN'),
#  ('zur', 'IN'),
#  ('Rechtfertigung', 'NN'),
#  ('zeigt', 'VB'),
#  ('Da', 'RB'),
#  ('ist', 'VB'),
#  ('durchaus', 'RB'),
#  ('Flugscham', 'JJ'),
#  ('dieses', 'WDT'),
#  ('neuzeitliche', 'JJ'),
#  ('Phänomen', 'NN'),
#  ('aber', 'CC'),
#  ('zugleich', 'RB'),
#  ('der', 'DT'),
#  ('verständliche', 'JJ'),
#  ('Wille', 'NN'),
#  ('sich', 'PRP'),
#  ('wenigstens', 'RB'),
#  ('den', 'DT'),
#  ('Familienurlaub', 'NN'),
#  ('nicht', 'RB'),
#  ('auch', 'RB'),
#  ('noch', 'RB'),
#  ('von', 'IN'),
#  ('Diskussionen', 'NN'),
#  ('vermiesen', 'NN'),
#  ('zu', 'IN'),
#  ('lassen', 'VB'),
#  ('„', 'NN'),
#  ('Ganz', 'NN'),
#  ('ehrlich', 'JJ'),
#  ('Wenn', 'IN'),
#  ('ich', 'JJ'),
#  ('das', 'DT'),
#  ('Wort', 'NN'),
#  ('Flugscham', 'JJ'),
#  ('höre', 'VB'),
#  ('kriege', 'NN'),
#  ('ich', 'PRP'),
#  ('Blutdruck', 'NN'),
#  ('Raoul', 'NNP'),
#  ('Hille', 'NNP'),
#  ('Chef', 'NN'),
#  ('des', 'DT'),
#  ('Hannover-Airports', 'NN'),
#  ('hat', 'VB'),
#  ('mit', 'IN'),
#  ('diesem', 'DT'),
#  ('Satz', 'NN'),
#  ('im', 'IN'),
#  ('Sommer', 'NN'),
#  ('Schlagzeilen', 'NN'),
#  ('gemacht', 'RP'),
#  ('In', 'IN'),
#  ('Deutschland', 'NNP'),
#  ('gingen', 'VB'),
#  ('0,3', 'CD'),
#  ('Prozent', 'NN'),
#  ('des', 'DT'),
#  ('CO2', 'JJ'),
#  ('-Ausstoßes', 'NN'),
#  ('auf', 'IN'),
#  ('Inlandsflüge', 'NN'),
#  ('zurück', 'RP'),
#  ('weltweit', 'JJ'),
#  ('mache', 'NN'),
#  ('der', 'DT'),
#  ('Luftverkehr', 'NN'),
#  ('zwischen', 'IN'),
#  ('2', 'CD'),
#  ('und', 'CC'),
#  ('3', 'CD'),
#  ('Prozent', 'NN'),
#  ('der', 'DT'),
#  ('Emissionen', 'NN'),
#  ('aus', 'RP'),
#  ('Moritz', 'NNP'),
#  ('Frankenberg', 'NNP'),
#  ('Archiv', 'NN'),
#  ('Tatsächlich', 'JJ'),
#  ('setzt', 'VB'),
#  ('ein', 'DT'),
#  ('Flug', 'NN'),
#  ('Hannover–Hurghada', 'NN'),
#  ('1797', 'CD'),
#  ('Kilogramm', 'NN'),
#  ('CO2', 'NN'),
#  ('frei', 'JJ'),
#  ('pro', 'IN'),
#  ('Person', 'NN'),
#  ('in', 'IN'),
#  ('einem', 'DT'),
#  ('durchschnittlichen', 'JJ'),
#  ('Flugzeug', 'NN'),
#  ('Weil', 'IN'),
#  ('das', 'DT'),
#  ('so', 'RB'),
#  ('abstrakt', 'JJ'),
#  ('klingt', 'VBN'),
#  ('Der', 'DT'),
#  ('Wert', 'NN'),
#  ('entspricht', 'VB'),
#  ('fast', 'VB'),
#  ('der', 'DT'),
#  ('Menge', 'NN'),
#  ('CO2', 'NN'),
#  ('die', 'DT'),
#  ('ein', 'DT'),
#  ('durchschnittliches', 'JJ'),
#  ('deutsches', 'JJ'),
#  ('Auto', 'NN'),
#  ('pro', 'IN'),
#  ('Jahr', 'NN'),
#  ('aus', 'IN'),
#  ('dem', 'DT'),
#  ('Auspuff', 'NN'),
#  ('bläst', 'NN'),
#  ('bei', 'IN'),
#  ('12', 'CD'),
#  ('000', 'CD'),
#  ('Kilometern', 'JJ'),
#  ('Fahrleistung', 'NN'),
#  ('Die', 'DT'),
#  ('Braunschweigerin', 'NN'),
#  ('hat', 'VB'),
#  ('also', 'RB'),
#  ('recht', 'RB'),
#  ('dass', 'IN'),
#  ('sie', 'JJ'),
#  ('mit', 'IN'),
#  ('ihrem', 'PRP$'),
#  ('täglichen', 'JJ'),
#  ('Radfahren', 'NN'),
#  ('der', 'DT'),
#  ('Umwelt', 'NN'),
#  ('viel', 'IN'),
#  ('Dreck', 'NNP'),
#  ('erspart', 'NNP'),
#  ('rechnerisch', 'VBN'),
#  ('hat', 'VB'),
#  ('sie', 'PRP'),
#  ('sich', 'PRP'),
#  ('ihren', 'PRP$'),
#  ('Flug', 'NN'),
#  ('nach', 'IN'),
#  ('Hurghada', 'NN'),
#  ('verdient', 'VB'),
#  ('Nur', 'RB'),
#  ('Ihre', 'PRP$'),
#  ('Familie', 'NN'),
#  ('wird', 'VB'),
#  ('wieder', 'IN'),
#  ('zurückfliegen', 'NN'),
#  ('Das', 'DT'),
#  ('sind', 'VB'),
#  ('dann', 'RB'),
#  ('pro', 'IN'),
#  ('Person', 'NN'),
#  ('schon', 'RB'),
#  ('3594', 'CD'),
#  ('Kilogramm', 'NN'),
#  ('CO2', 'NN'),
#  ('also', 'RB'),
#  ('die', 'DT'),
#  ('Fahrleistung', 'NN'),
#  ('von', 'IN'),
#  ('zwei', 'CD'),
#  ('Familienautos', 'NN'),
#  ('Schlaue', 'NN'),
#  ('Leute', 'NN'),
#  ('haben', 'VB'),
#  ('errechnet', 'NN'),
#  ('der', 'DT'),
#  ('durchschnittliche', 'JJ'),
#  ('Inder', 'NN'),
#  ('verbrauche', 'NN'),
#  ('1600', 'CD'),
#  ('Kilogramm', 'NN'),
#  ('CO2', 'NN'),
#  ('im', 'IN'),
#  ('Jahr', 'NN'),
#  ('Bei', 'IN'),
#  ('den', 'DT'),
#  ('Zahlen', 'NN'),
#  ('ahnt', 'NN'),
#  ('man', 'DT'),
#  ('dass', 'IN'),
#  ('zwar', 'RB'),
#  ('das', 'DT'),
#  ('Argument', 'NN'),
#  ('richtig', 'JJ'),
#  ('ist', 'VB'),
#  ('dass', 'RB'),
#  ('Deutschland', 'NNP'),
#  ('nur', 'RB'),
#  ('2', 'CD'),
#  ('Prozent', 'NN'),
#  ('der', 'DT'),
#  ('weltweiten', 'NN'),
#  ('CO2-Emissionen', 'JJ'),
#  ('ausmacht', 'NN'),
#  ('Aber', 'RB'),
#  ('dass', 'IN'),
#  ('jeder', 'DT'),
#  ('Einzelne', 'VB'),
#  ('durchaus', 'RB'),
#  ('etwas', 'DT'),
#  ('tun', 'VB'),
#  ('kann', 'VB'),
#  ('Könnte', 'NN'),
#  ('Jahrgangsfahrt', 'NN'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Côte', 'NN'),
#  ('d´Azur', 'NN'),
#  ('abgesagt', 'VBN'),
#  ('An', 'IN'),
#  ('der', 'DT'),
#  ('Schule', 'NN'),
#  ('von', 'IN'),
#  ('Anna', 'NNP'),
#  ('Janßen', 'NNP'),
#  ('2.', 'JJ'),
#  ('v', 'NN'),
#  ('li', 'NN'),
#  ('sind', 'VB'),
#  ('die', 'DT'),
#  ('Klimaveränderungen', 'JJ'),
#  ('Thema', 'NN'),
#  ('Und', 'CC'),
#  ('auch', 'RB'),
#  ('in', 'IN'),
#  ('ihrer', 'PRP$'),
#  ('Familie', 'NN'),
#  ('gibt', 'VB'),
#  ('es', 'PRP'),
#  ('ernsthafte', 'JJ'),
#  ('Debatten', 'NN'),
#  ('Vater', 'NN'),
#  ('Jörg', 'NNP'),
#  ('Janßen', 'NNP'),
#  ('re.', 'VB'),
#  ('mit', 'IN'),
#  ('Sohn', 'NN'),
#  ('Jonas', 'NNP'),
#  ('sagt', 'VB'),
#  ('„', 'NN'),
#  ('Deutschland', 'NNP'),
#  ('allein', 'RB'),
#  ('kann', 'VB'),
#  ('das', 'DT'),
#  ('Klimaproblem', 'NN'),
#  ('nicht', 'RB'),
#  ('lösen.', 'JJ'),
#  ('Mutter', 'NN'),
#  ('Monika', 'NNP'),
#  ('li', 'NN'),
#  ('ärgert', 'VB'),
#  ('sich', 'PRP'),
#  ('dass', 'RB'),
#  ('Flugtickets', 'NN'),
#  ('zu', 'RB'),
#  ('billig', 'JJ'),
#  ('und', 'CC'),
#  ('Bahntickets', 'NN'),
#  ('zu', 'TO'),
#  ('teuer', 'JJ'),
#  ('sind', 'VB'),
#  ('Moritz', 'NNP'),
#  ('Frankenberg', 'NNP'),
#  ('Familienwechsel', 'NNP'),
#  ('An', 'IN'),
#  ('der', 'DT'),
#  ('Schule', 'NN'),
#  ('der', 'DT'),
#  ('16-jährigen', 'NN'),
#  ('Anna', 'NNP'),
#  ('Janßen', 'NNP'),
#  ('haben', 'VB'),
#  ('sie', 'PRP'),
#  ('für', 'IN'),
#  ('kommendes', 'NN'),
#  ('Jahr', 'NN'),
#  ('die', 'DT'),
#  ('Jahrgangsfahrt', 'JJ'),
#  ('abgeblasen', 'NN'),
#  ('Es', 'PRP'),
#  ('sollte', 'MD'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Côte', 'NN'),
#  ('d´Azur', 'NN'),
#  ('gehen', 'VB'),
#  ('per', 'IN'),
#  ('Flugzeug', 'NN'),
#  ('Die', 'DT'),
#  ('Schule', 'NN'),
#  ('aber', 'VBN'),
#  ('hatte', 'VB'),
#  ('sich', 'PRP'),
#  ('gerade', 'RB'),
#  ('zur', 'IN'),
#  ('Klimaschule', 'NN'),
#  ('erklärt', 'RP'),
#  ('Anna', 'NNP'),
#  ('berichtet', 'NNP'),
#  ('die', 'DT'),
#  ('Côte-d´Azur-Tour', 'NN'),
#  ('habe', 'VB'),
#  ('„', 'NN'),
#  ('heftige', 'JJ'),
#  ('Debatten', 'NN'),
#  ('ausgelöst', 'NN'),
#  ('„', 'NN'),
#  ('jetzt', 'RB'),
#  ('fahren', 'VB'),
#  ('wir', 'PRP'),
#  ('mit', 'IN'),
#  ('dem', 'DT'),
#  ('Zug', 'NN'),
#  ('nach', 'IN'),
#  ('Colmar', 'NNP'),
#  ('ins', 'IN'),
#  ('Elsass', 'NNP'),
#  ('Niemand', 'NN'),
#  ('sage', 'VB'),
#  ('also', 'RP'),
#  ('die', 'DT'),
#  ('Klimabewegung', 'NN'),
#  ('der', 'DT'),
#  ('Kinder', 'NN'),
#  ('ändere', 'VB'),
#  ('nichts', 'DT'),
#  ('Aber', 'CC'),
#  ('hätte', 'VB'),
#  ('man', 'DT'),
#  ('nicht', 'RB'),
#  ('auch', 'RB'),
#  ('mit', 'IN'),
#  ('dem', 'DT'),
#  ('Zug', 'NN'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Côte', 'NN'),
#  ('fahren', 'VB'),
#  ('können', 'VB'),
#  ('„', 'NN'),
#  ('Das', 'DT'),
#  ('ist', 'VB'),
#  ('viel', 'IN'),
#  ('teurer', 'NN'),
#  ('als', 'IN'),
#  ('die', 'DT'),
#  ('Billigtickets', 'NN'),
#  ('der', 'DT'),
#  ('Flieger', 'NN'),
#  ('sagt', 'VB'),
#  ('Mutter', 'NN'),
#  ('Monika', 'NNP'),
#  ('Janßen', 'NNP'),
#  ('50', 'CD'),
#  ('„', 'NN'),
#  ('Wir', 'PRP'),
#  ('müssten', 'VB'),
#  ('eigentlich', 'JJ'),
#  ('bereit', 'RB'),
#  ('sein', 'VB'),
#  ('die', 'DT'),
#  ('Flüge', 'NNS'),
#  ('teurer', 'NN'),
#  ('zu', 'TO'),
#  ('machen', 'VB'),
#  ('und', 'CC'),
#  ('die', 'DT'),
#  ('Bahntickets', 'NN'),
#  ('preiswerter.', 'JJ'),
#  ('Das', 'DT'),
#  ('kann', 'VB'),
#  ('Vater', 'NN'),
#  ('Jörg', 'NNP'),
#  ('Janßen', 'NNP'),
#  ('50', 'CD'),
#  ('nicht', 'RB'),
#  ('so', 'RB'),
#  ('stehen', 'VB'),
#  ('lassen', 'VB'),
#  ('„', 'NN'),
#  ('Solange', 'NN'),
#  ('Trump', 'NN'),
#  ('seine', 'PRP$'),
#  ('Klimapolitik', 'NN'),
#  ('nicht', 'RB'),
#  ('ändert', 'VB'),
#  ('brauchen', 'RB'),
#  ('auch', 'WRB'),
#  ('wir', 'PRP'),
#  ('gar', 'RB'),
#  ('nichts', 'DT'),
#  ('zu', 'TO'),
#  ('verändern', 'VB'),
#  ('sagt', 'VB'),
#  ('er', 'PRP'),
#  ('„', 'NN'),
#  ('Deutschland', 'NNP'),
#  ('allein', 'RB'),
#  ('kann', 'VB'),
#  ('das', 'DT'),
#  ('Klimaproblem', 'NN'),
#  ('nicht', 'RB'),
#  ('lösen.', 'JJ'),
#  ('Und', 'RB'),
#  ('dass', 'IN'),
#  ('in', 'IN'),
#  ('Polen', 'NNP'),
#  ('„', 'NNP'),
#  ('jeder', 'JJ'),
#  ('Haushalt', 'NN'),
#  ('mit', 'IN'),
#  ('Briketts', 'NN'),
#  ('heizt', 'NN'),
#  ('und', 'CC'),
#  ('Kreuzfahrtschiffe', 'NN'),
#  ('ohnehin', 'RB'),
#  ('viel', 'RB'),
#  ('mehr', 'IN'),
#  ('Dreck', 'NN'),
#  ('in', 'IN'),
#  ('die', 'DT'),
#  ('Luft', 'NN'),
#  ('bliesen', 'NN'),
#  ('als', 'IN'),
#  ('Flieger', 'NN'),
#  ('Tochter', 'NN'),
#  ('und', 'CC'),
#  ('Ehefrau', 'NN'),
#  ('funkeln', 'VB'),
#  ('ihn', 'PRP'),
#  ('kritisch', 'JJ'),
#  ('an', 'RP'),
#  ('man', 'DT'),
#  ('ahnt', 'NN'),
#  ('dass', 'IN'),
#  ('diese', 'WDT'),
#  ('Diskussion', 'NN'),
#  ('schon', 'RB'),
#  ('etliche', 'DT'),
#  ('Male', 'NN'),
#  ('am', 'RB'),
#  ('Familientisch', 'JJ'),
#  ('geführt', 'VBN'),
#  ('wurde', 'VB'),
#  ('Jörg', 'NNP'),
#  ('Janßen', 'NNP'),
#  ('betreibt', 'NNP'),
#  ('eine', 'DT'),
#  ('Gärtnerei', 'NN'),
#  ('man', 'DT'),
#  ('will', 'MD'),
#  ('ihm', 'PRP'),
#  ('die', 'DT'),
#  ('Liebe', 'NN'),
#  ('zur', 'IN'),
#  ('Natur', 'NN'),
#  ('nicht', 'RB'),
#  ('absprechen', 'VB'),
#  ('Aber', 'CC'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Klimadebatte', 'NN'),
#  ('hat', 'VB'),
#  ('jeder', 'DT'),
#  ('seine', 'PRP$'),
#  ('eigenen', 'JJ'),
#  ('Argumentationen', 'NN'),
#  ('und', 'CC'),
#  ('Rechtfertigungen', 'NNS'),
#  ('fürs', 'NN'),
#  ('Handeln', 'VB'),
#  ('und', 'CC'),
#  ('jetzt', 'RB'),
#  ('will', 'MD'),
#  ('Familie', 'NN'),
#  ('Janßen', 'NN'),
#  ('ins', 'IN'),
#  ('westgriechische', 'JJ'),
#  ('Patras', 'NN'),
#  ('Mit', 'IN'),
#  ('dem', 'DT'),
#  ('Tesla', 'NN'),
#  ('zum', 'IN'),
#  ('Flughafen', 'NN'),
#  ('Hausarzt', 'NN'),
#  ('Karsten', 'NNP'),
#  ('Müller', 'NNP'),
#  ('hier', 'RB'),
#  ('mit', 'IN'),
#  ('Sohn', 'NNP'),
#  ('Vincent', 'NNP'),
#  ('hat', 'VB'),
#  ('mit', 'IN'),
#  ('seinen', 'PRP$'),
#  ('Kindern', 'NN'),
#  ('besprochen', 'VB'),
#  ('welche', 'WP'),
#  ('CO2-Minderungen', 'NN'),
#  ('sinnvoll', 'JJ'),
#  ('sind', 'VB'),
#  ('Moritz', 'NN'),
#  ('Frankenberg', 'NNP'),
#  ('Auch', 'RB'),
#  ('Karsten', 'NNP'),
#  ('Müller', 'NNP'),
#  ('47', 'CD'),
#  ('ist', 'NN'),
#  ('mit', 'IN'),
#  ('Frau', 'NN'),
#  ('und', 'CC'),
#  ('Kindern', 'NN'),
#  ('unterwegs', 'RP'),
#  ('Lanzarote', 'NN'),
#  ('ist', 'VB'),
#  ('das', 'DT'),
#  ('Ziel', 'NN'),
#  ('Die', 'DT'),
#  ('Insel', 'NN'),
#  ('lasse', 'JJ'),
#  ('sich', 'PRP'),
#  ('mit', 'IN'),
#  ('dem', 'DT'),
#  ('Auto', 'NN'),
#  ('ja', 'RB'),
#  ('nun', 'RB'),
#  ('mal', 'RB'),
#  ('schlecht', 'JJ'),
#  ('erreichen', 'VB'),
#  ('sagt', 'VB'),
#  ('er', 'PRP'),
#  ('und', 'CC'),
#  ('rechnet', 'NN'),
#  ('vor', 'RP'),
#  ('„', 'NN'),
#  ('Fliegen', 'NN'),
#  ('macht', 'VB'),
#  ('2', 'CD'),
#  ('bis', 'IN'),
#  ('3', 'CD'),
#  ('Prozent', 'NN'),
#  ('des', 'DT'),
#  ('CO2-Ausstoßes', 'NN'),
#  ('aus.', 'JJ'),
#  ('Er', 'PRP'),
#  ('ist', 'VB'),
#  ('Hautarzt', 'NN'),
#  ('hat', 'VB'),
#  ('viel', 'RB'),
#  ('auch', 'RB'),
#  ('mit', 'IN'),
#  ('Atemwegserkrankungen', 'NN'),
#  ('zu', 'TO'),
#  ('tun', 'VB'),
#  ('Deshalb', 'RB'),
#  ('hat', 'RB'),
#  ('er', 'PRP'),
#  ('gehandelt', 'VB'),
#  ('und', 'CC'),
#  ('versucht', 'RB'),
#  ('die', 'DT'),
#  ('Welt', 'NN'),
#  ('etwas', 'DT'),
#  ('besser', 'RB'),
#  ('zu', 'TO'),
#  ('machen', 'VB'),
#  ('Er', 'PRP'),
#  ('fährt', 'VB'),
#  ('den', 'DT'),
#  ('abgasfreien', 'NN'),
#  ('Tesla', 'NN'),
#  ('mit', 'IN'),
#  ('dem', 'WDT'),
#  ('die', 'DT'),
#  ('Familie', 'NN'),
#  ('auch', 'RB'),
#  ('zum', 'IN'),
#  ('Flughafen', 'NN'),
#  ('gekommen', 'VBN'),
#  ('ist', 'VB'),
#  ('Der', 'DT'),
#  ('Strom', 'NN'),
#  ('fürs', 'NN'),
#  ('Auto', 'NN'),
#  ('kommt', 'VB'),
#  ('aus', 'IN'),
#  ('der', 'DT'),
#  ('hauseigenen', 'NN'),
#  ('Solaranlage', 'NN'),
#  ('sodass', 'CC'),
#  ('Müller', 'NN'),
#  ('sich', 'PRP'),
#  ('das', 'DT'),
#  ('billige', 'JJ'),
#  ('Argument', 'NN'),
#  ('nicht', 'RB'),
#  ('ständig', 'RB'),
#  ('anhören', 'VB'),
#  ('muss', 'VB'),
#  ('sein', 'PRP$'),
#  ('Auto', 'NN'),
#  ('fahre', 'VBN'),
#  ('ja', 'RB'),
#  ('mit', 'IN'),
#  ('einem', 'DT'),
#  ('Strommix', 'NN'),
#  ('der', 'DT'),
#  ('Braunkohleabgase', 'NN'),
#  ('beinhaltet', 'VB'),
#  ('„', 'NN'),
#  ('Ich', 'PRP'),
#  ('habe', 'VB'),
#  ('mit', 'TO'),
#  ('meinen', 'PRP$'),
#  ('Kindern', 'NN'),
#  ('besprochen', 'VB'),
#  ('wie', 'IN'),
#  ('wir', 'JJ'),
#  ('CO2', 'NN'),
#  ('sparen', 'VB'),
#  ('können', 'VB'),
#  ('und', 'CC'),
#  ('was', 'WP'),
#  ('sinnvoll', 'JJ'),
#  ('ist', 'VB'),
#  ...]

# %% [markdown]
# https://textblob.readthedocs.io/en/dev/classifiers.html

# %% [raw]
# '''
#
# from textblob.classifiers import NaiveBayesClassifier
# #cl = NaiveBayesClassifier(train)
# for s in blob.sentences:
#     print(s)
#     print(s.classify())
#
# '''

# %%
text.split()
# Out:
# ['Flydays',
#  'for',
#  'Future',
#  'Als',
#  'hätte',
#  'es',
#  'keine',
#  'Klimaproteste',
#  'gegeben:',
#  'Schlangen',
#  'von',
#  'Familien',
#  'am',
#  'Abfertigungsschalter',
#  'im',
#  'Flughafen',
#  'Hannover-Langenhagen.',
#  '719.000',
#  'Fluggäste',
#  'wurden',
#  'hier',
#  'im',
#  'Oktober',
#  '2018',
#  'abgefertigt,',
#  'in',
#  'diesem',
#  'Jahr',
#  'rechnet',
#  'der',
#  'Airport',
#  'mit',
#  'der',
#  'gleichen',
#  'Zahl.',
#  'fotos:',
#  'Moritz',
#  'Frankenberg',
#  'Trotz',
#  'aller',
#  'Klimaproteste:',
#  'In',
#  'diesen',
#  'Herbstferien',
#  'fliegen',
#  'genauso',
#  'viele',
#  'Familien',
#  'vom',
#  'Flughafen',
#  'Hannover',
#  'ab',
#  'wie',
#  'im',
#  'Vorjahr.',
#  'Aber',
#  'vielfach',
#  'gehen',
#  'kontroverse',
#  'Debatten',
#  'im',
#  'Familienkreis',
#  'voraus.',
#  'Ein',
#  'Besuch',
#  'in',
#  'der',
#  'Abflugebene',
#  'des',
#  'Airports.',
#  'Von',
#  'Conrad',
#  'von',
#  'Meding',
#  'Hannover.',
#  'Die',
#  'Schlangen',
#  'an',
#  'den',
#  'Abfertigungsschaltern',
#  'sind',
#  'so',
#  'lang',
#  'wie',
#  'immer',
#  'zum',
#  'Ferienauftakt.',
#  'Als',
#  'wären',
#  'nicht',
#  'Zehntausende',
#  'Schüler',
#  'in',
#  'Schulstreik',
#  'getreten,',
#  'als',
#  'hätte',
#  'es',
#  'keine',
#  'Klimaproteste',
#  'auch',
#  'an',
#  'hannoverschen',
#  'Schulen',
#  'gegeben',
#  '–',
#  'übrigens',
#  'genau',
#  'im',
#  'zehnten',
#  'Monat',
#  'jetzt',
#  'schon.',
#  'Hurghada,',
#  'Mallorca,',
#  'Lanzarote,',
#  'Barcelona,',
#  'Heraklion,',
#  'Thessaloniki',
#  'sind',
#  'die',
#  'Flugziele',
#  'auf',
#  'der',
#  'großen',
#  'Airport-Tafel',
#  'an',
#  'diesem',
#  'Vormittag.',
#  'Und',
#  'darunter:',
#  'Familien',
#  'mit',
#  'Schulkindern,',
#  'die',
#  'dem',
#  'Schmuddelwetter',
#  'gen',
#  'Süden',
#  'entfliehen.',
#  'Mit',
#  'dem',
#  'Flieger.',
#  'Flydays',
#  'for',
#  'Future?',
#  '„Die',
#  'Maschinen',
#  'sind',
#  'gut',
#  'gebucht“,',
#  'bestätigt',
#  'Flughafensprecher',
#  'Sönke',
#  'Jacobsen',
#  'den',
#  'optischen',
#  'Eindruck,',
#  'den',
#  'die',
#  'Schlangen',
#  'an',
#  'den',
#  'Check-in-Schaltern',
#  'vermitteln.',
#  'Etwa',
#  '719',
#  '000',
#  'Fluggäste',
#  'habe',
#  'der',
#  'Airport',
#  'im',
#  'Oktober',
#  '2018',
#  'gezählt.',
#  'Für',
#  'diesen',
#  'Oktober',
#  'gehe',
#  'man',
#  'von',
#  '„annähernd',
#  'dem',
#  'gleichen',
#  'Niveau“',
#  'aus,',
#  'genaue',
#  'Zahlen',
#  'gibt',
#  'es',
#  'erst',
#  'am',
#  'Monatsende.',
#  '„Klimaschutz',
#  'ist',
#  'wichtig',
#  '–',
#  'aber',
#  'nicht',
#  'so,',
#  'dass',
#  'wir',
#  'dafür',
#  'Urlaub',
#  'opfern“:',
#  'Karina',
#  'Schmidt',
#  'mit',
#  'Tochter',
#  'Aylin',
#  'im',
#  'Flughafen',
#  'Hannover',
#  'auf',
#  'dem',
#  'Weg',
#  'nach',
#  'Hurghada.',
#  'Moritz',
#  'Frankenberg',
#  'Also:',
#  'Nichts',
#  'mit',
#  'Flugscham?',
#  'Macht',
#  'der',
#  'Bewusstseinswandel',
#  'Herbstferien?',
#  'Erscheint',
#  'die',
#  'Klimakrise',
#  'weniger',
#  'dramatisch,',
#  'wenn',
#  'man',
#  'dafür',
#  'Sonne',
#  'und',
#  'Sandstrand',
#  'aufgeben',
#  'müsste?',
#  '„Klimaschutz',
#  'ist',
#  'wichtig,',
#  'aber',
#  'nicht',
#  'so,',
#  'dass',
#  'wir',
#  'dafür',
#  'den',
#  'Urlaub',
#  'opfern“,',
#  'sagt',
#  'ganz',
#  'ehrlich',
#  'Karina',
#  'Schmidt.',
#  'Die',
#  '35-jährige',
#  'Physiotherapeutin',
#  'ist',
#  'mit',
#  'Tochter',
#  'Aylin',
#  '(15)',
#  'unterwegs',
#  'nach',
#  'Hurghada,',
#  'das',
#  'Sonne-und-Schnorchel-Paradies',
#  'am',
#  'Roten',
#  'Meer',
#  'in',
#  'Ägypten.',
#  'Klimaschutz',
#  'nicht',
#  'so',
#  'wichtig',
#  '–',
#  'darf',
#  'man',
#  'so',
#  'etwas',
#  'sagen',
#  'in',
#  'Zeiten',
#  'von',
#  'Klimaprotesten?',
#  '„Ja,',
#  'man',
#  'darf“,',
#  'sagt',
#  'auch',
#  'eine',
#  'Braunschweiger',
#  'Mutter,',
#  'die',
#  'mit',
#  'Mann',
#  'und',
#  'den',
#  '14-',
#  'und',
#  '17-jährigen',
#  'Kindern',
#  'Richtung',
#  'Süden',
#  'eincheckt.',
#  '„Ich',
#  'fahre',
#  '365',
#  'Tage',
#  'im',
#  'Jahr',
#  'mit',
#  'dem',
#  'Rad',
#  'zur',
#  'Arbeit“,',
#  'sagt',
#  'sie,',
#  '„ich',
#  'kaufe',
#  'sehr',
#  'bewusst',
#  'Lebensmittel',
#  'ein,',
#  'ich',
#  'werfe',
#  'davon',
#  'fast',
#  'nichts',
#  'weg,',
#  'wir',
#  'kaufen',
#  'nicht',
#  'Unmengen',
#  'an',
#  'Klamotten,',
#  'und',
#  'die',
#  'Kinder',
#  'haben',
#  'nicht',
#  'ständig',
#  'die',
#  'neuesten',
#  'Handys.',
#  'Ich',
#  'lasse',
#  'mir',
#  'nicht',
#  'unterstellen,',
#  'ich',
#  'sei',
#  'nicht',
#  'umweltbewusst.“',
#  'Allein',
#  'der',
#  'Drang',
#  'zur',
#  'Rechtfertigung',
#  'zeigt:',
#  'Da',
#  'ist',
#  'durchaus',
#  'Flugscham,',
#  'dieses',
#  'neuzeitliche',
#  'Phänomen,',
#  'aber',
#  'zugleich',
#  'der',
#  'verständliche',
#  'Wille,',
#  'sich',
#  'wenigstens',
#  'den',
#  'Familienurlaub',
#  'nicht',
#  'auch',
#  'noch',
#  'von',
#  'Diskussionen',
#  'vermiesen',
#  'zu',
#  'lassen.',
#  '„Ganz',
#  'ehrlich:',
#  'Wenn',
#  'ich',
#  'das',
#  'Wort',
#  'Flugscham',
#  'höre,',
#  'kriege',
#  'ich',
#  'Blutdruck“:',
#  'Raoul',
#  'Hille,',
#  'Chef',
#  'des',
#  'Hannover-Airports,',
#  'hat',
#  'mit',
#  'diesem',
#  'Satz',
#  'im',
#  'Sommer',
#  'Schlagzeilen',
#  'gemacht.',
#  'In',
#  'Deutschland',
#  'gingen',
#  '0,3',
#  'Prozent',
#  'des',
#  'CO2',
#  '-Ausstoßes',
#  'auf',
#  'Inlandsflüge',
#  'zurück,',
#  'weltweit',
#  'mache',
#  'der',
#  'Luftverkehr',
#  'zwischen',
#  '2',
#  'und',
#  '3',
#  'Prozent',
#  'der',
#  'Emissionen',
#  'aus.',
#  'Moritz',
#  'Frankenberg',
#  '(Archiv)',
#  'Tatsächlich',
#  'setzt',
#  'ein',
#  'Flug',
#  'Hannover–Hurghada',
#  '1797',
#  'Kilogramm',
#  'CO2',
#  'frei,',
#  'pro',
#  'Person,',
#  'in',
#  'einem',
#  'durchschnittlichen',
#  'Flugzeug.',
#  'Weil',
#  'das',
#  'so',
#  'abstrakt',
#  'klingt:',
#  'Der',
#  'Wert',
#  'entspricht',
#  'fast',
#  'der',
#  'Menge',
#  'CO2,',
#  'die',
#  'ein',
#  'durchschnittliches',
#  'deutsches',
#  'Auto',
#  'pro',
#  'Jahr',
#  'aus',
#  'dem',
#  'Auspuff',
#  'bläst,',
#  'bei',
#  '12',
#  '000',
#  'Kilometern',
#  'Fahrleistung.',
#  'Die',
#  'Braunschweigerin',
#  'hat',
#  'also',
#  'recht,',
#  'dass',
#  'sie',
#  'mit',
#  'ihrem',
#  'täglichen',
#  'Radfahren',
#  'der',
#  'Umwelt',
#  'viel',
#  'Dreck',
#  'erspart,',
#  'rechnerisch',
#  'hat',
#  'sie',
#  'sich',
#  'ihren',
#  'Flug',
#  'nach',
#  'Hurghada',
#  'verdient.',
#  'Nur:',
#  'Ihre',
#  'Familie',
#  'wird',
#  'wieder',
#  'zurückfliegen.',
#  'Das',
#  'sind',
#  'dann',
#  'pro',
#  'Person',
#  'schon',
#  '3594',
#  'Kilogramm',
#  'CO2,',
#  'also',
#  'die',
#  'Fahrleistung',
#  'von',
#  'zwei',
#  'Familienautos.',
#  'Schlaue',
#  'Leute',
#  'haben',
#  'errechnet,',
#  'der',
#  'durchschnittliche',
#  'Inder',
#  'verbrauche',
#  '1600',
#  'Kilogramm',
#  'CO2',
#  'im',
#  'Jahr.',
#  'Bei',
#  'den',
#  'Zahlen',
#  'ahnt',
#  'man,',
#  'dass',
#  'zwar',
#  'das',
#  'Argument',
#  'richtig',
#  'ist,',
#  'dass',
#  'Deutschland',
#  'nur',
#  '2',
#  'Prozent',
#  'der',
#  'weltweiten',
#  'CO2-Emissionen',
#  'ausmacht.',
#  'Aber',
#  'dass',
#  'jeder',
#  'Einzelne',
#  'durchaus',
#  'etwas',
#  'tun',
#  'kann.',
#  'Könnte.',
#  'Jahrgangsfahrt',
#  'an',
#  'die',
#  'Côte',
#  'd´Azur',
#  'abgesagt:',
#  'An',
#  'der',
#  'Schule',
#  'von',
#  'Anna',
#  'Janßen',
#  '(2.',
#  'v.',
#  'li.)',
#  'sind',
#  'die',
#  'Klimaveränderungen',
#  'Thema.',
#  'Und',
#  'auch',
#  'in',
#  'ihrer',
#  'Familie',
#  'gibt',
#  'es',
#  'ernsthafte',
#  'Debatten.',
#  'Vater',
#  'Jörg',
#  'Janßen',
#  '(re.,',
#  'mit',
#  'Sohn',
#  'Jonas)',
#  'sagt:',
#  '„Deutschland',
#  'allein',
#  'kann',
#  'das',
#  'Klimaproblem',
#  'nicht',
#  'lösen.“',
#  'Mutter',
#  'Monika',
#  '(li.)',
#  'ärgert',
#  'sich,',
#  'dass',
#  'Flugtickets',
#  'zu',
#  'billig',
#  'und',
#  'Bahntickets',
#  'zu',
#  'teuer',
#  'sind.',
#  'Moritz',
#  'Frankenberg',
#  'Familienwechsel.',
#  'An',
#  'der',
#  'Schule',
#  'der',
#  '16-jährigen',
#  'Anna',
#  'Janßen',
#  'haben',
#  'sie',
#  'für',
#  'kommendes',
#  'Jahr',
#  'die',
#  'Jahrgangsfahrt',
#  'abgeblasen.',
#  'Es',
#  'sollte',
#  'an',
#  'die',
#  'Côte',
#  'd´Azur',
#  'gehen,',
#  'per',
#  'Flugzeug.',
#  'Die',
#  'Schule',
#  'aber',
#  'hatte',
#  'sich',
#  'gerade',
#  'zur',
#  'Klimaschule',
#  'erklärt.',
#  'Anna',
#  'berichtet,',
#  'die',
#  'Côte-d´Azur-Tour',
#  'habe',
#  '„heftige',
#  'Debatten“',
#  'ausgelöst,',
#  '„jetzt',
#  'fahren',
#  'wir',
#  'mit',
#  'dem',
#  'Zug',
#  'nach',
#  'Colmar',
#  'ins',
#  'Elsass“.',
#  'Niemand',
#  'sage',
#  'also,',
#  'die',
#  'Klimabewegung',
#  'der',
#  'Kinder',
#  'ändere',
#  'nichts.',
#  'Aber',
#  'hätte',
#  'man',
#  'nicht',
#  'auch',
#  'mit',
#  'dem',
#  'Zug',
#  'an',
#  'die',
#  'Côte',
#  'fahren',
#  'können?',
#  '„Das',
#  'ist',
#  'viel',
#  'teurer',
#  'als',
#  'die',
#  'Billigtickets',
#  'der',
#  'Flieger“,',
#  'sagt',
#  'Mutter',
#  'Monika',
#  'Janßen',
#  '(50):',
#  '„Wir',
#  'müssten',
#  'eigentlich',
#  'bereit',
#  'sein,',
#  'die',
#  'Flüge',
#  'teurer',
#  'zu',
#  'machen',
#  'und',
#  'die',
#  'Bahntickets',
#  'preiswerter.“',
#  'Das',
#  'kann',
#  'Vater',
#  'Jörg',
#  'Janßen',
#  '(50)',
#  'nicht',
#  'so',
#  'stehen',
#  'lassen.',
#  '„Solange',
#  'Trump',
#  'seine',
#  'Klimapolitik',
#  'nicht',
#  'ändert,',
#  'brauchen',
#  'auch',
#  'wir',
#  'gar',
#  'nichts',
#  'zu',
#  'verändern“,',
#  'sagt',
#  'er:',
#  '„Deutschland',
#  'allein',
#  'kann',
#  'das',
#  'Klimaproblem',
#  'nicht',
#  'lösen.“',
#  'Und',
#  'dass',
#  'in',
#  'Polen',
#  '„jeder',
#  'Haushalt',
#  'mit',
#  'Briketts',
#  'heizt“',
#  'und',
#  'Kreuzfahrtschiffe',
#  'ohnehin',
#  'viel',
#  'mehr',
#  'Dreck',
#  'in',
#  'die',
#  'Luft',
#  'bliesen',
#  'als',
#  'Flieger.',
#  'Tochter',
#  'und',
#  'Ehefrau',
#  'funkeln',
#  'ihn',
#  'kritisch',
#  'an,',
#  'man',
#  'ahnt,',
#  'dass',
#  'diese',
#  'Diskussion',
#  'schon',
#  'etliche',
#  'Male',
#  'am',
#  'Familientisch',
#  'geführt',
#  'wurde.',
#  'Jörg',
#  'Janßen',
#  'betreibt',
#  'eine',
#  'Gärtnerei,',
#  'man',
#  'will',
#  'ihm',
#  'die',
#  'Liebe',
#  'zur',
#  'Natur',
#  'nicht',
#  'absprechen.',
#  'Aber',
#  'in',
#  'der',
#  'Klimadebatte',
#  'hat',
#  'jeder',
#  'seine',
#  'eigenen',
#  'Argumentationen',
#  'und',
#  'Rechtfertigungen',
#  'fürs',
#  'Handeln,',
#  'und',
#  'jetzt',
#  'will',
#  'Familie',
#  'Janßen',
#  'ins',
#  'westgriechische',
#  'Patras.',
#  'Mit',
#  'dem',
#  'Tesla',
#  'zum',
#  'Flughafen:',
#  'Hausarzt',
#  'Karsten',
#  'Müller',
#  '(hier',
#  'mit',
#  'Sohn',
#  'Vincent)',
#  'hat',
#  'mit',
#  'seinen',
#  'Kindern',
#  'besprochen,',
#  'welche',
#  'CO2-Minderungen',
#  'sinnvoll',
#  'sind.',
#  'Moritz',
#  'Frankenberg',
#  'Auch',
#  'Karsten',
#  'Müller',
#  '(47)',
#  'ist',
#  'mit',
#  'Frau',
#  'und',
#  'Kindern',
#  'unterwegs,',
#  'Lanzarote',
#  'ist',
#  'das',
#  'Ziel.',
#  'Die',
#  'Insel',
#  'lasse',
#  'sich',
#  'mit',
#  'dem',
#  'Auto',
#  'ja',
#  'nun',
#  'mal',
#  'schlecht',
#  'erreichen,',
#  'sagt',
#  'er,',
#  'und',
#  'rechnet',
#  'vor:',
#  '„Fliegen',
#  'macht',
#  '2',
#  'bis',
#  '3',
#  'Prozent',
#  'des',
#  'CO2-Ausstoßes',
#  'aus.“',
#  'Er',
#  'ist',
#  'Hautarzt,',
#  'hat',
#  'viel',
#  'auch',
#  'mit',
#  'Atemwegserkrankungen',
#  'zu',
#  'tun.',
#  'Deshalb',
#  'hat',
#  'er',
#  'gehandelt',
#  'und',
#  'versucht,',
#  'die',
#  'Welt',
#  'etwas',
#  'besser',
#  'zu',
#  'machen.',
#  'Er',
#  'fährt',
#  'den',
#  'abgasfreien',
#  'Tesla,',
#  'mit',
#  'dem',
#  'die',
#  'Familie',
#  'auch',
#  'zum',
#  'Flughafen',
#  'gekommen',
#  'ist.',
#  'Der',
#  'Strom',
#  'fürs',
#  'Auto',
#  'kommt',
#  'aus',
#  'der',
#  'hauseigenen',
#  'Solaranlage,',
#  'sodass',
#  'Müller',
#  'sich',
#  'das',
#  'billige',
#  'Argument',
#  'nicht',
#  'ständig',
#  'anhören',
#  'muss,',
#  'sein',
#  'Auto',
#  'fahre',
#  'ja',
#  'mit',
#  'einem',
#  'Strommix,',
#  'der',
#  'Braunkohleabgase',
#  'beinhaltet.',
#  '„Ich',
#  'habe',
#  'mit',
#  'meinen',
#  'Kindern',
#  'besprochen,',
#  'wie',
#  'wir',
#  'CO2',
#  'sparen',
#  'können',
#  'und',
#  'was',
#  'sinnvoll',
#  'ist“,',
#  'sagt',
#  'er,',
#  'als',
#  'er',
#  'Sohn',
#  'Vincent',
#  '(10)',
#  'an',
#  'sich',
#  'drückt.',
#  'Dann',
#  'geht',
#  'es',
#  'nach',
#  'Lanzarote.',
#  'Man',
#  'kann',
#  'vielleicht',
#  ...]

# %%
# dictionary = corpora.Dictionary(text.split()) ... DAS läuft so noch nicht ...

# %%
import textacy

# %%
# !ls
# Out:
# CIO14062019.ipynb  LICENSE		   textblob_6_Oktober_2019.ipynb
# DHB.txt		   nlp_MK_13.7.2019.ipynb  Textblob.ipynb
# DKB.txt		   README.md		   textblobTestMK01.py
# EasyScraper.ipynb  spacyTest03.ipynb	   textblobTestMK02.py

# %%
from textacy import preprocessing

# %%
file_contents = ""
with open("DHB.txt", "r") as file_handle:
    for line in file_handle.readlines():
        print(line)
        file_contents += line.replace("-", "_")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# __________________________________________________________________________
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  IT-Strategie
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
#
#
#
#
# INHALT
#
#
#
# 1  MANAGEMENT SUMMARY ..................................................................................... 6
#
#
#
# 2  KAPITELÜBERSICHT .............................................................................................. 8
#
#
#
# 3  SITUATION DER ABTEILUNG INFORMATIONSMANAGEMENT UND
#
# BANKBETRIEB............................................................................................................... 9
#
#
#
# 3.1  Organisationsstruktur und Personal ............................................................................ 9
#
#
#
# 3.2
#
#
#
# IT-Anwendungs-Architektur .......................................................................................... 9
#
#
#
# 3.3
#
#
#
# IT-Infra-Architektur ....................................................................................................... 12
#
#
#
# 3.4  Kosten........................................................................................................................... 12
#
#
#
# 3.5  Handlungsbedarf ......................................................................................................... 12
#
#
#
# 4  STRATEGISCHE ZIELE UND MAßNAHMEN DER DÜSSELDORFER
#
# HYPOTHEKENBANK AG ............................................................................................. 14
#
#
#
# 4.1  Generelle Ziele ............................................................................................................. 14
#
#
#
# 4.2  Geschäftsspezifische Ziele ......................................................................................... 14
#
#
#
# 4.3  Umsetzung ................................................................................................................... 15
#
#
#
# 4.4  Auswirkungen auf die IT-Struktur ............................................................................... 15
#
#
#
# 5
#
#
#
# IT-INFRASTRUKTUR-ARCHITEKTUR .................................................................. 17
#
#
#
# 5.1
#
#
#
# Software as a Service / Cloud ..................................................................................... 17
#
#
#
# 5.2  Web 2.0 ......................................................................................................................... 18
#
#
#
# 5.3
#
#
#
# ITIL ................................................................................................................................ 19
#
#
#
# 5.4  Kennzahlen (Key Performance Indicators) ................................................................. 19
#
#
#
# 5.5
#
#
#
# Service- und Produktkatalog ....................................................................................... 21
#
#
#
# 6
#
#
#
# IT-ANWENDUNGSARCHITEKTUR ....................................................................... 23
#
#
#
# 6.1  Grundlegende Prinzipien ............................................................................................. 23
#
#
#
# 6.2
#
#
#
# IT-Bebauungsplan (siehe Anlage) ............................................................................... 23
#
#
#
# 6.3
#
#
#
# SAP-Anwendungen ...................................................................................................... 23
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 2 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 6.4  Business Warehouse ................................................................................................... 24
#
#
#
# 6.5
#
#
#
# SEPA-Fähigkeit ............................................................................................................ 24
#
#
#
# 6.6
#
#
#
# PMS ............................................................................................................................... 25
#
#
#
# 6.7  Marktdatenversorgung ................................................................................................ 27
#
# Reuters .................................................................................................................................... 27
#
# Bloomberg ............................................................................................................................... 27
#
#
#
# 6.7.1
#
# 6.7.2
#
#
#
# 6.8  Workflow ....................................................................................................................... 27
#
# SAP Workflow ......................................................................................................................... 27
#
#
#
# 6.8.1
#
#
#
# 6.9
#
#
#
# Textverarbeitung .......................................................................................................... 27
#
#
#
# 6.10  Weitere Konsolidierung ............................................................................................... 28
#
# Ablösung Lotus Notes nach Aufbewahrungsfristen von COR-PARIS .................................... 28
#
# ACCESS .................................................................................................................................. 28
#
#
#
# 6.10.1
#
# 6.10.2
#
#
#
# 7  PROZESSMANAGEMENT DER IT-ANWENDUNGEN .......................................... 28
#
#
#
# 7.1
#
#
#
# Steuerung und Überwachung der operativen IT-Prozesse ....................................... 28
#
#
#
# 7.2
#
#
#
# Testmanagement (Dokumentation, Verzahnung, Testfälle) ...................................... 29
#
#
#
# 7.3
#
#
#
# ITIL (Change, Incident, Configuration) ....................................................................... 30
#
#
#
# 8
#
#
#
# IT-TECHNOLOGIE-STRATEGIE ............................................................................ 30
#
#
#
# 8.1  Grundlegende Prinzipien ............................................................................................. 30
#
# Infrastrukturwandel im SAN Speicherumfeld .......................................................................... 32
#
# Produktionsprinzipien .............................................................................................................. 33
#
#
#
# 8.1.1
#
# 8.1.2
#
#
#
# 8.2
#
#
#
# IT-Betrieb ...................................................................................................................... 34
#
# 7 x 24 Stunden-Betrieb ........................................................................................................... 34
#
# Steuerung und Überwachung ................................................................................................. 34
#
# Schicht-Betrieb ........................................................................................................................ 35
#
# Daten- und Middlewaresysteme.............................................................................................. 35
#
# SAP-Basisbetreuung und Releasemanagement .................................................................... 35
#
# Outsourcing Strategie ............................................................................................................. 35
#
#
#
# 8.2.1
#
# 8.2.2
#
# 8.2.3
#
# 8.2.4
#
# 8.2.5
#
# 8.2.6
#
#
#
# 8.3
#
#
#
# Systemplattformen ....................................................................................................... 36
#
# Plattformen ......................................................................... Fehler! Textmarke nicht definiert.
#
# Betriebssysteme ...................................................................................................................... 36
#
# Datenbanken ........................................................................................................................... 36
#
#
#
# 8.3.1
#
# 8.3.2
#
# 8.3.3
#
#
#
# 8.4  Datenhaltung und -archivierung ................................................................................. 36
#
# Normalbetrieb .......................................................................................................................... 36
#
# Archivierungssystem ............................................................................................................... 37
#
#
#
# 8.4.1
#
# 8.4.2
#
#
#
# 8.5  Netzwerke ..................................................................................................................... 37
#
# Daten-Netzwerk....................................................................................................................... 37
#
#
#
# 8.5.1
#
#
#
# 8.6
#
#
#
# End- und Peripherie-Geräte ......................................................................................... 38
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 3 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 8.7
#
#
#
# IT-Arbeitsplatz, Authentifizierung und Berechtigungen ............................................ 39
#
# IT-Arbeitsplatz ......................................................................................................................... 39
#
# Benutzer-Authentifizierung ...................................................................................................... 39
#
# Verwaltung von Berechtigungen ............................................................................................. 39
#
#
#
# 8.7.1
#
# 8.7.2
#
# 8.7.3
#
#
#
# 9
#
#
#
# IT-SICHERHEIT ...................................................................................................... 40
#
#
#
# 9.1
#
#
#
# Zugriffssicherheit ......................................................................................................... 40
#
#
#
# 9.2  Ausfallsicherheit .......................................................................................................... 40
#
#
#
# 9.3  Gebäudesicherheit ....................................................................................................... 41
#
#
#
# 9.4  Kommunikationssicherheit ......................................................................................... 41
#
#
#
# 10  UMWELTSTRATEGIE (GREEN IT) ........................................................................ 43
#
#
#
# 10.1  Zentraler Serverbetrieb ................................................................................................ 43
#
#
#
# 10.2  Energieeffizienz am Arbeitsplatz ................................................................................ 43
#
#
#
# 11  ORGANISATIONSSTRATEGIE ............................................................................. 44
#
#
#
# 11.1  Aktueller Stand der Organisation ............................................................................... 44
#
# Aufgaben ................................................................................................................................. 44
#
# Instrumente (Dokumentation) .................................................................................................. 44
#
# Fazit ......................................................................................................................................... 45
#
#
#
# 11.1.1
#
# 11.1.2
#
# 11.1.3
#
#
#
# 11.2  Handlungsbedarf im Bereich der Bankorganisation ................................................. 46
#
# 11.2.1  Optimierung Ablauforganisation .............................................................................................. 46
#
# 11.2.2  Weiterentwicklung OHB .......................................................................................................... 46
#
# 11.2.3  Optimierung Aufbauorganisation ............................................................................................ 47
#
# 11.2.4  Mitwirken bei der Umsetzung gesetzlicher Änderungen ......................................................... 47
#
#
#
# 12  IT/BANKORGANISATION ...................................................................................... 47
#
#
#
# 12.1  Organisationsstruktur ................................................................................................. 47
#
#
#
# 12.2  Sourcing ....................................................................................................................... 47
#
#
#
# 12.3  Personalentwicklung ................................................................................................... 48
#
#
#
# 13  IT-KOSTEN ............................................................................................................. 49
#
#
#
# 13.1  Entwicklung der IT-Kosten .......................................................................................... 49
#
#
#
# 13.2  Kostensteuerung ......................................................................................................... 49
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 4 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# Genehmigung
#
#
#
#
#
#
#
# Das vorliegende IT-Strategie-Papier beinhaltet die Fortschreibung der Informationstechnologie
#
# (IT) in der Düsseldorfer Hypothekenbank AG. Es trägt sowohl der Entwicklung der Bank in der
#
# Fortschreibung ihrer Geschäftsstrategie, als auch der Entwicklung des IT-Marktes Rechnung.
#
#
#
# Dieses Papier bildet die Grundlage für die IT-Entwicklung der Düsseldorfer Hypothekenbank AG
#
# in den nächsten vier Jahren und muss daher durch den Vorstand genehmigt werden.
#
# Dies wird in einer Vorstandssitzung per Vorstandsvorlage vollzogen.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wahrung der Vertraulichkeit
#
#
#
# Der Inhalt dieses Dokuments ist Eigentum der Düsseldorfer Hypothekenbank AG. Er darf ohne
#
# schriftliche Genehmigung der Düsseldorfer Hypothekenbank AG weder ganz noch teilweise
#
# dupliziert, an Dritte weitergegeben oder anderweitig veröffentlich werden. Dies gilt nicht für Ko-
#
# pien, die für interne Verwendung bestimmt sind.
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 5 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 1  Management Summary
#
#
#
# Das Kerngeschäft der Düsseldorfer Hypothekenbank AG ist die gewerbliche Immobilienfinanzie-
#
# rung im Inland und in ausgewählten Ballungszentren im angrenzenden europäischen Ausland.
#
# Kundenzielgruppe sind professionelle Immobilieninvestoren, die ein breites Spektrum an inte-
#
# grierten und kapitalmarktorientierten Finanzierungs- und Zusatzleistungen anfordern.
#
#
#
# Strategische Neuausrichtung der Bank seit 2012:
#
#
#
# •  Oberstes Geschäftsziel ist die Reorganisation der Bank zu einem fokussierten, nachhaltig
#
#
#
# operierenden und rentablen Unternehmen.
#
#
#
#
#
# •  Die Bank konzentriert sich auf die gewerbliche Immobilienfinanzierung als Kerngeschäft und
#
# dabei insbesondere auf den Ausbau des spezifischen Know-hows in der Geschäftsakquisiti-
#
# on, der Prozessgestaltung und dem Risikomanagement.
#
#
#
#
#
# •  Das Kapitalmarktgeschäft (einschließlich Staatskreditgeschäft) wird durch ein aktives Ma-
#
#
#
# nagement zurückgefahren und ist in Zukunft nunmehr ein komplementäres Geschäftsfeld zur
#
# Immobilienfinanzierung.
#
#
#
#
#
# •  Mit ihrer überschaubaren Personalausstattung und ihrer effizienten Unternehmensorganisa-
#
# tion verfügt die DHB über wettbewerbsfähige Kostenstrukturen. Es gilt, diesen Wettbewerbs-
#
# vorteil zu bewahren und auch durch Kooperationen auszubauen.
#
#
#
#
#
# Aus der Zieldefinition ergibt sich, dass vorwiegend komplexe (auch hinsichtlich der Refinanzie-
#
# rung) Geschäfte in geringer Stückzahl zu bearbeiten sind.
#
# In den nächsten Jahren ist im Kerngeschäft mit einem hohen (vielfachem) Wachstum  zu rech-
#
# nen.
#
#
#
#
#
# Bei der Ableitung der IT-Strategie aus den Geschäftszielen und -schwerpunkten sind zwei we-
#
# sentliche Aspekte zu berücksichtigen:
#
#
#
# 1.  Einerseits ist die IT-Strategie vorrangig auf die Anforderungen der Kernbank ausgerich-
#
#
#
# tet und implementiert. Die Geschäftsprozesse sind im Wesentlichen definiert aber die
#
# Mengengerüste in Bezug auf Neugeschäft und Gesamtportfolio erfordern einen hohen
#
# Anpassungsbedarf hinsichtlich Effektivität und Effizienz. Die IT ist hier gefordert dyna-
#
# misch den Wachstumsprozess zu fördern.
#
#
#
# 2.  Zum anderen ist das Geschäftsmodell in der Praxis bewährt und wird gemäß der Strate-
#
#
#
# gie keinen grundsätzlichen prozessualen Änderungen unterworfen. Da der Fokus nun
#
# mehr in der mengenorientierten Justage entsprechend der Kunden- und Markterforder-
#
# nisse wie auch den gesetzlichen und regulatorischen Anforderungen liegt, ist die jetzige
#
# IT-Plattform als Kernelement der Anwendungslandschaft anzusehen. Entsprechend der
#
# genannten Einflüsse sind hier Anforderungen der Fachbereiche in einem stabilen Um-
#
# feld vorzunehmen.
#
#
#
# Im Rahmen der konkreten Ausarbeitung der IT-Strategie wurden in dem vorliegenden Strate-
#
# giepapier die wesentlichen inhaltlichen und organisatorischen Bereiche in der
#
# IT/Bankorganisation untersucht und unter Beachtung der angeführten Rahmenbedingungen die
#
# konkreten Auswirkungen auf die IT-Strategie ausgearbeitet.
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 6 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# Neben den allgemeinen Architekturrichtlinien und der grundsätzlichen Positionierung in Bezug
#
# auf IT-technische Trends und Schwerpunkte wurden die Rahmenbedingungen für die zukünfti-
#
# ge Weiterentwicklung der  Anwendungs- und Systemlandschaft formuliert. Dies umfasst neben
#
# der technologischen Strategie auch technische Infrastrukturthemen und die Organisation des
#
# IT-Betriebes inklusive der Sourcing-Strategie für die Düsseldorfer Hypothekenbank AG.
#
#
#
# Als wesentliche Maßnahmen sind die weitere Konsolidierung der eingesetzten Technologien
#
# und der Anwendungslandschaft vorzusehen, die Feinjustage der Standard-
#
# Anwendungssoftware sowie der weitere Ausbau des Outsourcing in geschäftsunkritischen Be-
#
# reichen. Die wesentlichen Kernelemente der Anwendungsarchitektur bilden hierbei SAP als
#
# Buchungsmaschine und PMS als Handels- und Risikomaschine.
#
#
#
# Zur Sicherstellung der IT-Sicherheit werden diverse Maßnahmen auf den Gebieten Zugriffs-
#
# schutz, Systemausfall und Archivierung umgesetzt.
#
#
#
# Im Bereich der Bankorganisation wird aktuell die derzeitige Dokumentations-Plattform geprüft
#
# und im Laufe des Jahres 2015 abgelöst, um zukünftig die Bereitstellung aller benötigten Infor-
#
# mationen für das Tagesgeschäft der Mitarbeiter in schneller, aktueller, übersichtlicher, verständ-
#
# licher Form zu gewährleisten.
#
#
#
# In der Personalentwicklung wird das zukünftige Anforderungsprofil der IT-Mitarbeiter sowie der
#
# IT-Koordinatoren in den Fachbereichen und das Schulungskonzept zu entwickeln sein, welches
#
# die notwendige Steigerung der Innovationsfähigkeit gewährleistet.
#
#
#
# Bei den IT-Kosten ist mittelfristig von einer leichten Reduktion auszugehen. Insbesondere
#
# nachdem  in 2014 die wesentlichen Organisationsänderungen abgeschlossen sind. Parallel wird
#
# die Steuerung der IT-Kosten durch zusätzliche Maßnahmen optimiert. Zielsetzung ist dabei die
#
# kontinuierliche Erhöhung der Kostentransparenz in der Kostenrechnungssystematik.
#
#
#
# Das Projektportfolio der Bank findet in der IT-Strategie Berücksichtigung, insofern Ressourcen
#
# und Budgets seitens der IT zur Verfügung gestellt werden sowie die IT grundsätzlich flexible
#
# Erweiterungsmöglichkeiten der Systeme anbietet.
#
#
#
# Die Umsetzung der IT-Strategie soll im Rahmen der IT-Maßnahmenplanung und der IT-
#
# Kostenplanung erfolgen. Der Vorstand wird regelmäßig über den aktuellen Stand der Umset-
#
# zung informiert.
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 7 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 2  Kapitelübersicht
#
#
#
# In Kapitel 3 wird die aktuelle IT-Landschaft der Düsseldorfer Hypothekenbank AG be-
#
# schrieben.
#
#
#
# In Kapitel 4 werden strategisch relevante unternehmerische Ziele und Maßnahmen aufge-
#
# führt und erläutert. Aus ihnen leitet sich ein Großteil der strategischen Ziele und Maßnahmen
#
# der IT ab.
#
#
#
# Andere IT-Maßnahmen begründen sich aus den IT-Infrastruktur-Architektur, die in
#
# Kapitel 5 – ausgehend von aktuellen Markttrends unter Berücksichtigung Düsseldorfer Hypo-
#
# thekenbank AG spezifischer Randbedingungen –  aufgestellt werden.
#
#
#
# Die IT-Anwendungsstrategie in Kapitel 6 behandelt die zukünftige Entwicklung der einzelnen,
#
# das Leistungsspektrum der IT umfassenden, anwendungsbezogenen Produkte. In die hier auf-
#
# geführten Ziele und Maßnahmen fließen sowohl Anforderungen aus der Unternehmensstrategie
#
# (Kapitel 4) als auch Vorgaben aus dem IT-Infrastruktur-Architektur-Konzept (Kapitel 5) ein.
#
#
#
# In Kapitel 7 (Prozessmanagement der IT-Anwendungen) wird dargestellt, wie im Servicema-
#
# nagement  der IT unter Kosten-/Nutzengesichtspunkten ein hoher Automationsgrad angestrebt
#
# wird.
#
#
#
# Kapitel 8 stellt die Strategie zur IT-Technologie vor, die vornehmlich für die Konzeption und
#
# Aufrechterhaltung des IT-Betriebes verantwortlich ist und von einem entsprechenden Out-
#
# sourcer gefordert sind. Hier werden strategische Ziele und Maßnahmen zu Themen wie Hard-
#
# ware-Ausstattung, Datenhaltung und -sicherung, Netzwerktechnik und -kommunikation bis hin
#
# zu Gebäude- und Ausfallsicherheit vorgestellt.
#
#
#
# Kapitel 9 stellt die technischen als auch organisatorischen Vorkehrungen dar, die auf  ver-
#
# schiedensten Ebenen getroffen werden damit die IT-Sicherheit gewährleistet ist.
#
#
#
# Kapitel 10 stellt die Umweltstrategie im IT Umfeld (Green IT) vor, die auf die Einsparung von
#
# Primärenergie und damit die Verminderung der CO2 Emissionen zielt.
#
#
#
# In Kapitel 11 (Bankorganisation) erfolgt neben der aktuellen Darstellung der Bankorganisation
#
# die Darstellung der zukünftigen Anforderungen.
#
#
#
# Ziele und Maßnahmen zu Personalentwicklung, Personaleinsatz und Aufbauorganisation wer-
#
# den im Kapitel 12 (Personalstrategie) vorgestellt.
#
#
#
# Kapitel 13 beinhaltet die IT-Kostenstruktur und beschreibt Ansätze zur Erhöhung der Kos-
#
# tensteuerung und -transparenz.
#
#
#
# Aus der Strategie werden Maßnahmen abgeleitet, die in den kommenden Jahren umgesetzt
#
# oder zumindest angestoßen werden.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 8 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 3  Situation der Abteilung Informationsmanagement und Bankbetrieb
#
#
#
# 3.1  Organisationsstruktur und Personal
#
#
#
#
#
# Der SAP- IT-Betrieb ist derzeit zur IMS (IBM Mittelstand Systeme) ausgelagert. Ebenso unter-
#
# liegen die internen Services der Infrastruktur dem Outsourcing zur IKB-Data. Die Koordination
#
# und Kontrolle der Outsourcer erfolgt über die Abteilungsleitung der ITB.
#
#
#
# Die derzeitige Organisationsstruktur der DHB Informationsmanagement und Bankbetrieb stellt
#
# sich wie folgt dar:
#
#
#
# Informationsmanagement und Bankbetrieb
#
# Leiter Hr. Thiele; Vertreter H. Jung (Erweiterte Geschäftsleitung);
#
# Vertreter Bankbetrieb:  Fr. Kirstein
#
#
#
# Bankbetrieb:
#
# Verwaltung/ Organisation/ Service
#
#
#
# Fr.Kirstein
#
# Hr. Haack
#
# Hr. Giertz
#
#
#
#
#
# Informationsmanagement
#
#
#
#
#
# BraCor GmbH
#
# IKB-Data
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3.2
#
#
#
# IT-Anwendungs-Architektur
#
#
#
#
#
# Derzeit nutzt die Bank SAP-Systeme mit den branchenunabhängigen Modulen für die Finanz-
#
# buchhaltung und das Kostencontrolling. Als bankenspezifische SAP-Software-Module kommen
#
# das Darlehensmodul (CML) sowie das Wertpapiermodul (CFM) zum Einsatz. Die Module für
#
# Banksteuerung (SEM) und Bauträgermodul / Modul für das Einlagengeschäft (BCA) sind instal-
#
# liert, aber nicht produktiv im Einsatz.
#
#
#
# Aktiv-Seite:
#
# Neben dem SAP-Standard wird zusätzlich eine speziell für Hypothekenbanken entwickelte
#
# Software (MBS: Mortgage Banking Solution) eingesetzt, welche durch die iBS, Wiesbaden, ver-
#
# trieben wird.
#
#
#
# Wichtige Buchungsvorgänge wie Stornobuchungen, Rücklastschriften oder Ausfälle von leis-
#
# tungsgestörten Darlehen verbleiben in der Bearbeitung der Buchhaltung. Die Buchhaltung ist
#
# ferner zuständig für die Abstimmung der Haupt- und Nebenbuchsalden. Die Sollstellung für Zin-
#
# sen und Tilgung wird täglich im Rahmen eines automatisierten Ablaufs gebucht und von der
#
# Zahlungsabwicklung weiterverarbeitet.
#
#
#
# Passiv-Seite:
#
# In der Abteilung Treasury Operations / Deckungsmanagement werden im Wesentlichen sämtli-
#
# che Handelsgeschäfte Wertpapiere, Geld, Devisen und Derivate sowie Schuldschein- / Kom-
#
# munaldarlehen und Namenspapiere systemtechnisch erfasst und gepflegt. Aktuell erfolgt dieses
#
# im SAP- und im PMS-System (Portfolio und Risiko Management System der Firma much-net).
#
# Geplant ist, dass bis Mitte 2015 die Doppeleingabe auf der Passiv-Seite entfällt und nach einer
#
# Erfassung im PMS-System vollintegriert die Geschäfte nach SAP übernommen werden. Agio- /
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 9 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# Disagio-Abgrenzung, Sollstellung (Zins und Tilgung) und Bewertung werden vom System ma-
#
# schinell vorgenommen. Die Nebenbuchhaltungen sind integriert mit der Haupt- bzw. Finanz-
#
# buchhaltung verbunden.
#
#
#
# Hauptbuchhaltung:
#
# Anhand der Monatsumsätze wird eine detaillierte Kontrollrechnung für alle Geschäftsarten er-
#
# stellt und dem Ergebnis der Buchhaltung gegenübergestellt; Abweichungen werden geklärt. Die
#
# Zahlungsabwicklung innerhalb der Finanzbuchhaltung wird beleghaft durchgeführt. Es erfolgt
#
# eine manuelle Zuordnung von Zahlungseingängen auf gebuchte „Offene Posten“ und deren
#
# Ausgleich im SAP-System. Als Schnittstelle für die Verbindung zur ausführenden Bank dienen
#
# unsere Outsourcing-Partner für den Zahlungsverkehr, die Firmen van den Berg und EFIS.
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 10 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# In der folgenden Skizze ist die Anwendungsarchitektur 2014 dargestellt.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 11 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 3.3
#
#
#
# IT-Infra-Architektur
#
#
#
#
#
#
#
#
#
#
#
#
#
# Die nachfolgende Skizze zeigt die Standort Struktur in der Zusammenarbeit mit der IKB-Data
#
# GmbH und IBM / IMS auf.
#
#
#
#
#
#
#
# Stand  01.04.2014
#
#
#
#
#
#
#
# 3.4  Kosten
#
#
#
#
#
#
#
#
#
# Durch die SAP-Einführung aus dem Jahr 2012 können die Kosten im eingeschwungenen er-
#
# heblich reduziert werden. Die Ursachen hierfür liegen insbesondere in den Betreiberkosten der
#
# SAP-Lösung und der Kooperation durch gemeinsame Entwicklung und Benutzerbetreuung der
#
# Anwendungsmodule.
#
#
#
#
#
# 3.5  Handlungsbedarf
#
#
#
#
#
# Im nachfolgenden sind einige Punkte aufgeführt in denen generell ein Handlungsbedarf gese-
#
# hen wird. In den nachfolgenden Kapiteln wird auf die einzelnen Punkte eingegangen.
#
#
#
# Im Bereich der Informationsmanagement:
#
#
#
# •  Optimierung der Struktur- und Prozessorganisation (insbesondere auch mit den IT-
#
#
#
# Systemen und der Integration von SAP und PMS)
#
#
#
# •  Releasewechsel Meldewesen und PMS
#
# •  Weitere Standardisierung der SAP-Landschaft (Wegfall MBS-add ons)
#
# •  Ausbau wirksames Kostencontrolling
#
# •  Durchführung regelmäßiger IT-Benchmarks ab 2015
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 12 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# •  Festlegung von weiteren KPI’s für die IT
#
#
#
#
#
#
#
# Im Bereich der Organisation:
#
#
#
# •  Einführung / Ausbau eines wirksamen Kostencontrolling
#
# •  Begleitung von Prozessoptimierungen Optimierung der Ablauforganisation durch elekt-
#
#
#
# ronischen Workflowsystem
#
#
#
# •  Überarbeitung des Organisationshandbuches und Aufbau einer verbesserten elektroni-
#
#
#
# schen Plattform
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 13 von 50
#
#
#
#
# IT -Strategie
#
#
#
# 4  Strategische Ziele und Maßnahmen der Düsseldorfer Hypothekenbank AG
#
#
#
# Hier werden zunächst grob die wichtigsten strategischen Ziele und Maßnahmen der Düsseldor-
#
# fer Hypothekenbank AG aufgeführt. Diese bilden den Ausgangspunkt für die IT-Strategie.
#
#
#
# 4.1  Generelle Ziele
#
#
#
#
#
# Die Düsseldorfer Hypothekenbank AG positioniert sich als Spezialist für gewerbliche Immobili-
#
# enfinanzierungen im Inland und in ausgewählten Ballungszentren im angrenzenden europäi-
#
# schen Ausland. Kundenzielgruppe sind professionelle Immobilieninvestoren, die ein breites
#
# Spektrum an integrierten und kapitalmarktorientierten Finanzierungs- und Zusatzleistungen an-
#
# fordern. Die Bank verfolgt seit dem Übergang auf den neuen Eigentümer die folgende strategi-
#
# sche Neuausrichtung:
#
#
#
# •  Oberstes Geschäftsziel ist die Reorganisation der Bank zu einem fokussierten, nachhal-
#
#
#
# tig operierenden und rentablen Unternehmen.
#
#
#
#
#
# •  Die Bank konzentriert sich auf die gewerbliche Immobilienfinanzierung als Kerngeschäft
#
# und dabei insbesondere auf den Ausbau des spezifischen Know-hows in der Geschäfts-
#
# akquisition, der Prozessgestaltung und dem Risikomanagement.
#
#
#
#
#
# •  Das Kapitalmarktgeschäft (einschließlich Staatskreditgeschäft) wird durch ein aktives
#
#
#
# Management zurückgefahren und ist in Zukunft nunmehr ein komplementäres Ge-
#
# schäftsfeld zur Immobilienfinanzierung.
#
#
#
#
#
# •  Mit ihrer überschaubaren Personalausstattung und ihrer effizienten Unternehmensorga-
#
# nisation verfügt die DHB über wettbewerbsfähige Kostenstrukturen. Es gilt, diesen Wett-
#
# bewerbsvorteil zu bewahren und beispielsweise durch Kooperationen auszubauen.
#
#
#
# Rahmenbedingungen
#
#
#
# Hieraus lassen sich für die IT-Strategie folgende wesentlichen Leitplanken ableiten:
#
#
#
#
#
# •  Flexibilität bei der Unterstützung der Restrukturierung und der Neuausrichtung
#
#
#
#
#
#
#
#
#
#
#
# •  Wirtschaftliche Geschäftsprozesse mit hohem Automatisierungsgrad und geringer Per-
#
#
#
# •
#
#
#
# sonalausstattung
#
#
#
# IT ist kein Kerngeschäft – Outsourcing von IT-Services wenn Leistungen im Markt  effek-
#
# tiver und effizienter sind und auch alle aufsichtsrechtlichen Rahmenbedingungen erfül-
#
# len.
#
#
#
# Dieses Geschäftsmodell erfordert im Immobiliengeschäft erhebliche Umstellungs- und
#
# Aufbauarbeiten. Darüber hinaus liegt der Fokus auf laufenden Feinausrichtungen ent-
#
# sprechend der Kunden- und Markterfordernisse sowie der gesetzlichen bzw. regulatori-
#
# schen Anforderungen.
#
#
#
# 4.2  Geschäftsspezifische Ziele
#
#
#
# Die Eckpunkte des Geschäftsmodells sind wie folgt definiert:
#
# •  Die Bank konzentriert sich auf den deutschen Markt sowie Finanzierungen in ausgewählten
#
#
#
# Ballungszentren im angrenzenden europäischen Ausland.
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 14 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# •  Zielkunden sind professionelle Immobilienkunden aus dem In- und Ausland. Es werden
#
#
#
# grundsätzlich alle marktgängigen Objektarten – Büroobjekte, Handelsimmobilien, Lo-
#
# gistikzentren und Wohngebäude (gewerblich, d.h. Mehrfamilienhaus) finanziert; Spezia-
#
# limmobilien wie z.B. Pflegeheime und Hotels werden in geringerem Umfang selektiv fi-
#
# nanziert
#
#
#
# •  Kerngeschäftsfeld der Bank ist die Finanzierung mittelgroßer Transaktionen mit einem
#
# Finanzierungsvolumen zwischen ca. 10 Mio. Euro und ca. 50 Mio. Euro, in Einzelfällen
#
# auch darüber hinaus
#
#
#
# •  Schwerpunktmäßig werden am Markt wieder platzierbare Kredite herein genommen;
#
#
#
# grundsätzlich stehen drei Exit-Kanäle zur Verfügung, wobei der Fokus auf Pfandbriefen
#
# liegt, aber auch Syndizierungen und Verbriefungen strategisch angestrebt werden
#
# •  Die Abwicklung und Verwertung notleidender Kredite werden von der Bank betreut.
#
#
#
# 4.3  Umsetzung
#
#
#
#
#
# Aus der Zieldefinition ergeben sich unmittelbar Schlussfolgerungen für die Fortführung der Ge-
#
# schäftsstrategie:
#
#
#
# •  Das  Geschäftsmodell  ist  in  der  Immobilienfinanzierung  verbunden  mit  einem  deutlich
#
#
#
# steigendem jährlichen Neugeschäft
#
#
#
# •  Die Bank ist an einem zentralen Standort präsent
#
# •  Hinsichtlich der schlanken Aufstellung und Spezialisierung der Bank ist eine Anzahl von
#
#
#
# ca. 70 Mitarbeitern im Kerngeschäftsbereich längerfristig realistisch
#
#
#
#
#
# Insgesamt bedeutet dies, dass vorwiegend komplexe (auch hinsichtlich der Refinanzierung)
#
# Geschäfte in geringer Stückzahl zu bearbeiten sind.
#
# In den nächsten Jahren ist im Kerngeschäft mit einem hohen (vielfachen) Wachstum zu rech-
#
# nen.
#
#
#
# 4.4  Auswirkungen auf die IT-Struktur
#
#
#
# Bei der Ableitung der IT-Strategie aus den Geschäftszielen und -schwerpunkten sind zwei we-
#
# sentliche Aspekte zu berücksichtigen:
#
#
#
# 1.  Einerseits ist die IT-Strategie vorrangig auf die Anforderungen der Kernbank ausgerich-
#
#
#
# tet und implementiert. Die Geschäftsprozesse sind im Wesentlichen definiert aber die
#
# Mengengerüste in Bezug auf Neugeschäft und Gesamtportfolio erfordern einen hohen
#
# Anpassungsbedarf hinsichtlich Effektivität und Effinzienz. Die IT ist hier gefordert dyna-
#
# misch den Wachstumsprozess zu fördern.
#
#
#
# 2.  Zum anderen ist das Geschäftsmodell in der Praxis bewährt und wird gemäß der Strate-
#
#
#
# gie keinen grundsätzlichen prozessualen Änderungen unterworfen. Da der Fokus nun
#
# mehr in der mengenorientierten Justage entsprechend der Kunden- und Markterforder-
#
# nisse wie auch den gesetzlichen und regulatorischen Anforderungen liegt, ist die jetzige
#
# IT-Plattform als Kernelement der Anwendungslandschaft anzusehen. Entsprechend der
#
# genannten Einflüsse sind hier Anforderungen der Fachbereiche in einem stabilen Um-
#
# feld vorzunehmen.
#
#
#
# Unter dem Aspekt der Stabilität und des Aufbaues sind nun im Systemkontext die Potenziale in
#
# Bezug auf
#
#
#
# •  Anwendungsarchitektur,
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 15 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# IT-Sicherheit,
#
#
#
# •  Systemarchitektur,
#
# •
#
# •
#
# •
#
#
#
# IT-Organisation,
#
#
#
# IT-Kosten
#
#
#
# kritisch zu betrachten und im Hinblick auf die Anforderungen des Tagesgeschäfts anzupassen
#
# bzw. zu optimieren.
#
#
#
# Durch die Anwendungslandschaft der Düsseldorfer Hypothekenbank AG wurde die IT-
#
# Unterstützung der Bankfunktionalitäten in den letzten zwei Jahren verbessert bzw. auf Basis
#
# des Turnarounds des Hauses sukzessive ausgebaut.
#
#
#
#
#
# Im Bereich der Kreditanbahnung und Abwicklung wurden die vorhandenen Anwendungen und
#
# Funktionen zur Unterstützung der Anbahnungsphase und der Bestandsverwaltung weiter ge-
#
# nutzt Dies gilt auch für die Syndizierung und die Verwaltung von syndizierten Krediten.
#
#
#
# Für die Refinanzierung wurde die IT-technische Unterstützung der Verbriefungstransaktionen
#
# und die Abbildung der Pfandbriefrefinanzierung in SAP unter dem Modul CML Core Banking
#
# Mortgage Loans in den letzten Jahren weiter ausgebaut. Durch ausgeprägte Schnittstellen zum
#
# Management für Finanzprodukte, dem Meldewesen und dem Zahlungsverkehr wurde ein den
#
# Anforderungen entsprechender Automatisierungsgrad erreicht. Verbindungen zum Hauptbuch,
#
# den Debitoren- und Kreditoren-Nebenbüchern sowie dem Controlling sind durch die Standard-
#
# Software gewährleistet
#
# Die Prozesse im Umfeld des Analytical Banking wurden weitgehend unter PMS (System der
#
# much-net) ausgebaut. Das Reporting basiert auf Datenbanken, die über Schnittstellen aus den
#
# verschiedenen Systemen gefüllt werden. Optimierungen sind aktuelle in der Analyse.
#
# Zur Stärkung der Vertriebsstruktur, die auf Grund der neuen Ausrichtung auf den deutschen
#
# Markt und den gewerblichen Zielmarkt sowohl hinsichtlich der geographischen Ausrichtung als
#
# auch auf Grund des angestrebten Zielsegmentes neue technische Bearbeitungswerkzeuge be-
#
# nötigt, soll in Zukunft das Deal-Team besser unterstützt werden. Die Geschwindigkeit des Deal-
#
# Teams als echten Wettbewerbsfaktor der Düsseldorfer Hypothekenbank AG noch besser aus-
#
# zunutzen, kann durch IT verstärkt werden.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 16 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# IT-Infrastruktur-Architektur
#
#
#
# 5
#
# Der Begriff IT-Infrastruktur-Architektur bezeichnet den konzeptionellen Aufbau der Anwen-
#
# dungssysteme bei der Düsseldorfer Hypothekenbank AG. Im Folgenden werden diejenigen As-
#
# pekte der IT-Infrastruktur-Architektur beschrieben, die für eine effiziente und effektive Umset-
#
# zung der strategischen IT-Ziele und damit auch der Unternehmensziele maßgeblich sind.
#
# Vor allem aus den Zielen Flexibilität und effiziente Kostenstruktur ergeben sich prinzipielle An-
#
# forderungen an die IT-Architektur in der Düsseldorfer Hypothekenbank AG:
#
#
#
# (cid:1)  Hohe  Anpassungsfähigkeit  an  sich  schnell  verändernde  Geschäftsprozesse  Verkür-
#
#
#
# zung der Produkt-Auslieferungszyklen (Time-to-Market)
#
#
#
# (cid:1)  Konsequente  Verfolgung  einer  minimum-Vendor-Strategie  ermöglicht  Kosteneffizienz
#
#
#
# durch Reduzierung der Plattformvielfalt
#
#
#
# (cid:1)  Vermehrter  Einsatz  von  Standard-Software  bzw.  Standard-Komponenten  senkt  die
#
# Wartungskosten und ermöglicht die Umwidmung von Wartungsressourcen für die Um-
#
# setzung neuer Anforderungen
#
#
#
# (cid:1)  Bei Erweiterungen der IT-Landschaft ist einerseits die Kosteneffizienz zu berücksichti-
#
# gen, aber andererseits sind Erweiterungen auch so flexibel zu gestalten, dass sie auf
#
# Veränderungen im Geschäftsmodell reagieren können
#
#
#
#
#
# SAP und PMS werden als Kernelemente der Anwendungslandschaft betrachtet. Die Systeme
#
# sind produktiv und konsequent auf die Bedürfnisse der Bank ausgerichtet. Es handelt sich bei
#
# diesen Anwendungssystemen um auf dem IT-Markt etablierte Systeme, so dass Support in die-
#
# sem Bereich langfristig gewährleistet ist.
#
# Daneben wird die IT-Architektur auch durch technische Innovationen beeinflusst. Die derzeit
#
# aktuellen IT-Technologie-Trends und die technologische Ausrichtung der o.g. Vendoren auf
#
# dem IT-Markt wurden bei der Konzeption dieser IT-Architektur berücksichtigt.
#
# Die hier vorgestellten Konzepte zur strategischen Ausrichtung der zukünftigen Düsseldorfer
#
# Hypothekenbank AG IT-Architektur werden bei der Konzeption und Entwicklung neuer Anwen-
#
# dungen, bei Konsolidierungsmaßnahmen und bei der Auswahl von Fremdprodukten und
#
# Fremdleistungen verbindlichen Charakter haben.
#
#
#
# 5.1  Software as a Service / Cloud
#
#
#
#
#
# Die Begriffe Software as a Service (SaaS) und Cloud-Computing sind mittlerweile in der IT sy-
#
# nonym zu verwenden. Hierbei steht im Vordergrund, dass ein Anbieter Software zur Verfügung
#
# stellt und diese betreibt. Der Anwender kann nun auf den Rechnern des Anbieters die zu nut-
#
# zende Software (as a Service) aufrufen, mit dieser arbeiten und sich nach dem Erreichen des
#
# gewünschten Ergebnisses wieder abmelden. Er zahlt für diesen Service „on demand“ also nur
#
# für die tatsächliche Nutzung. Cloud-Computing ist lediglich eine Erweiterung dieser SaaS-
#
# Funktionalität dahingehend, dass das System des Anbieters auf Rechnern verteilt (Cloud) lie-
#
# gen kann und die Software auf einem dieser Rechner ausgeführt wird.
#
#
#
# Anbieter – wie z.B. SAP – setzen in Zukunft auf solche Services, um ihre Produkte (quasi aus
#
# einer Hand) dem Anwender zur Verfügung zu stellen. Mit dieser Technologie wird man sich in
#
# Zukunft von einem Rechenzentrum als Service-Provider zunehmend lösen können. Allerdings
#
# ist die Technologie heute auf weniger kritische Anwendungen beschränkt, da Sicherheitsme-
#
# chanismen im Internet verteilten Anwendungen noch nicht den erwünschten Reifegrad haben.
#
# Dennoch gehört dieses Thema explizit in die IT-Strategie der Düsseldorfer Hypothekenbank
#
# AG, da sich in absehbarer Zeit Potenziale vom Markt abschöpfen lassen.
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 17 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# Ziel
#
# Ziel der Düsseldorfer Hypothekenbank AG ist es, auf dem Markt angebotene Services im
#
# Gleichgewicht von Preis-/Leistungsverhältnis von professionellen Anbietern zu nutzen. Die IT
#
# hat in diesem Fall die starke Rolle des „Enablers“, da sich Unternehmensprozesse, die nicht
#
# unmittelbar einen Beitrag zur Wertschöpfung haben im Sinne des Business Process Outsour-
#
# cing auslagern lassen.
#
#
#
# 5.2  Web 2.0
#
#
#
#
#
# Während das Internet in den 90er Jahren des letzten Jahrhunderts einen Hype auslöste und die
#
# bis dahin eingefahrenen Gewohnheiten von PC-Usern in revolutionärer Weise nachhaltig beein-
#
# flusste, ist die weitere Entwicklung des Internets eher evolutionär zu sehen. Es haben sich in
#
# dieser Fortentwicklung (bekannt unter dem Stichwort Web 2.0, das langsam durch das Schlag-
#
# wort Social Media abgelöst wird) eine Reihe interaktiver und kollaborativer Elemente in der
#
# Mensch-Maschine-Mensch Interaktion manifestiert, die den Anwender im Umgang mit dem In-
#
# ternet selbständiger und intuitiver machten. Diese Arbeitsweisen sind mittlerweile im privaten
#
# Gebrauch von Internet und IT derart etabliert, dass es naheliegend ist, das „Look, Work & Feel“
#
# dieser Art zu arbeiten in die professionellen Umgebungen zu integrieren. Das bedeutet, dass
#
# zum einen Standardsoftware diesem Thema Rechnung tragen wird und im Zusammenhang mit
#
# der Bereitstellung in einer Cloud (s.o.) solche Arbeitsweisen sinnvoll sind.
#
#
#
# Hierbei gewinnen sog. Mashups (von engl. „to mash“: „vermischen“) bei der Bereitstellung von
#
# Diensten zunehmend an Bedeutung.  Es ist nicht mehr die Regel, die einzelnen Dienste ge-
#
# trennt zu nutzen, sondern die Webinhalte verschiedener Dienste werden über offene Program-
#
# mierschnittstellen nahtlos zu neuen Diensten verbunden.
#
#
#
# Daher wird die Unterscheidung zwischen Intra- und Extranet zunehmend fließend. Der Anwen-
#
# der ist vielmehr in eine Portalumgebung eingebettet, in der er sich aufgrund seiner Benutzerbe-
#
# rechtigung bewegt. Damit wird der Übergang zwischen verschiedenen Anwendungen und
#
# Diensten erleichtert.
#
#
#
# Die SAP-Software bietet in ihrer Weiterentwicklung diese Portallösung an, so dass dies mehr
#
# und mehr zum Standard gehört. Darüber hinaus lassen sich durch Open Source-Produkte frei
#
# zugängliche Anwendungen in ein Portal integrieren.
#
#
#
# Das zurzeit bekannteste Produkt des Web 2.0 ist das sog. WIKI (hawaiisch: „schnell“), dass es
#
# ermöglicht, in Kollaboration (unter Beachtung einer Versionierung) Texte in einer Gemeinschaft
#
# zu entwerfen. Dieses Vorgehen bietet sich für Dokumentation (Handbücher, Org-
#
# Dokumentation, Protokolle etc.) sehr gut an, da eine Abstimmung nicht formalisiert, sondern
#
# direkt und online unter Berücksichtigung der Nachvollziehbarkeit (wer hat was geändert) eben
#
# schnell erfolgt.
#
#
#
# Für die Projektarbeit gewinnen in Projektteams „Weblogs“ zunehmend an Bedeutung. Ein
#
# Weblog wird oftmals als Tagebuch im Internet bezeichnet. Ein festgelegter Autorenkreis ver-
#
# fasst Einträge, die in chronologisch umgekehrter Reihenfolge aufgelistet werden. Der Leser
#
# kann Kommentare zu den Einträgen verfassen.
#
#
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 18 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# Ziel
#
# Die Düsseldorfer Hypothekenbank AG wird diesem Anspruch in der Weiterentwicklung ihrer
#
# Anwendungslandschaft gerecht, in dem zum einen zunehmend die Techniken von WIKI inte-
#
# griert werden und zum anderen mit dem neuen SAP Release die technischen Grundlagen für
#
# eine Portallösung gegeben ist.
#
#
#
# 5.3
#
#
#
# ITIL
#
#
#
#
#
# Die IT Infrastructure Library (ITIL) ist eine Sammlung von Best Practices in einer Reihe von
#
# Publikationen, die eine mögliche Umsetzung eines IT-Service-Managements (ITSM) beschrei-
#
# ben und inzwischen international als De-facto-Standard hierfür gelten. In dem Regel- und Defi-
#
# nitionswerk werden die für den Betrieb einer IT-Infrastruktur notwendigen Prozesse, die Auf-
#
# bauorganisation und die Werkzeuge beschrieben. Die ITIL orientiert sich an dem durch den IT-
#
# Betrieb zu erbringenden wirtschaftlichen Mehrwert für den Nutzer. Dabei werden die Planung,
#
# Erbringung, Unterstützung und Effizienz-Optimierung von IT-Serviceleistungen im Hinblick auf
#
# ihren Nutzen als relevante Faktoren zur Erreichung der Geschäftsziele eines Unternehmens
#
# betrachtet.
#
#
#
# ITIL schließt die Lücke zwischen strategischer Unternehmensplanung und die daraus resultie-
#
# rende effiziente Umsetzung in IT (strategische Informationsplanung). Das Regelwerk beschreibt
#
# in mehr als 40 (!) Büchern die Vorgehensweise mit Methoden und Verfahren, wie ein reibungs-
#
# loser IT-Betrieb aufgestellt sein sollte.
#
#
#
# Da die IT der Düsseldorfer Hypothekenbank AG in großen Teilen bereits ausgelagert ist und
#
# somit die meisten Verfahren (IT-Sicherheit, Service-Desk, IT-Continuity Management etc.) beim
#
# „Outsourcer“ Anwendung finden, sollten die Verfahren dieses Best Practice Ansatzes effizient
#
# und gezielt in der Düsseldorfer Hypothekenbank AG eingesetzt werden. In Form eines „Cherry
#
# Picking“ aus den Vorgaben der IT Infrastructure Library lassen sich noch Potenziale zur Steige-
#
# rung der Effizienz des bestehenden IT-Betriebes in der Düsseldorfer Hypothekenbank AG ab-
#
# schöpfen.
#
#
#
# Ziel
#
# So wird Potenzial in der Kontrolle und Weiterentwicklung von Applikationen und deren Steue-
#
# rung gesehen. Konkret bedeutet dies, dass die Düsseldorfer Hypothekenbank AG (als Anwen-
#
# der) mit ihren Anforderungen architekturkonform gemäß der SAP (als Softwarevendor) Anforde-
#
# rungen an die Servicer (Hoster) in diesem Dreiklang umsetzen kann. Darüber hinaus können
#
# bei Applikationsneuerungen bzw. –erweiterungen die Fachbereichsanforderungen in Form ei-
#
# nes verbesserten Testmanagement dediziert nachvollzogen werden.
#
#
#
# Die Standardsoftware von SAP bietet hier mit dem Solution Manager als in der Lizenz verfügba-
#
# res Paket die Chance, diese Anforderungen kostenneutral in der IT der Düsseldorfer Hypothe-
#
# kenbank AG umzusetzen. Darüber hinaus muss das sog. Change Control Management mit dem
#
# „Outsourcer“ verbessert werden, so dass vor allem (unvorhergesehene) Abbrüche in der Nacht-
#
# verarbeitung (Incidents) aufgrund von Daten- oder Prozessfehler noch besser nachvollziehbar
#
# und damit noch schneller behebbar werden.
#
#
#
#
#
# 5.4  Kennzahlen (Key Performance Indicators)
#
#
#
#
#
# Das Ziel von Kennzahlen (Key Performance Indicators, KPIs) ist es, komplexe Sachverhalte in
#
# Unternehmen in relativ einfacher Form darzustellen. Dabei steht insbesondere der Aspekt der
#
# optimalen Aggregation im Vordergrund, da zum einen die Anzahl der Kennzahlen möglichst
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 19 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# gering und sie selbst möglichst einfach gehalten werden sollten. Andererseits sollten sie aber
#
# auch den realen Sachverhalt möglichst originalgetreu und unverfälscht wiedergeben. Diese Ori-
#
# ginaltreue kann nur begrenzt erreicht werden, da die Ermittlung der Kennzahlen von der Genau-
#
# igkeit der Messmethode und von stochastischen Schwankungen abhängig ist. Außerdem kön-
#
# nen einzelne Kennzahlen unterschiedlich interpretiert werden, da unter Umständen weitere In-
#
# formationen für eine genaue Beurteilung des Sachverhalts fehlen.
#
#
#
# Diese Nachteile einzelner Kennzahlen können teilweise durch Kennzahlensysteme behoben
#
# werden. Unter einem Kennzahlensystem versteht man eine geordnete Gesamtheit von Kenn-
#
# zahlen, die in sachlich sinnvoller Beziehung zueinander stehen und somit einen bestimmten
#
# Sachverhalt vollständig beschreiben sollen. Hier hat sich in der Praxis die Balanced Scorecard
#
# (BSC) bewährt. Es handelt sich um ein Kennzahlensystem, bestehend aus finanziellen und
#
# nichtfinanziellen Größen, das die verschiedenen Dimensionen (Kunden, Finanzen, interne Pro-
#
# zesse, Potenzial) eines Unternehmens gleichberechtigt nebeneinander darstellen kann. Die
#
# BSC stellt eine Weiterentwicklung konventioneller Kennzahlensysteme dar (z.B. des DuPont-
#
# oder ZVEI-Kennzahlensystems). Durch die BSC sollen alle Mitarbeiter und Manager motiviert
#
# und in die Lage versetzt werden, die Unternehmensstrategie erfolgreich umzusetzen. Die BSC
#
# wird deshalb oftmals mit einem Flugzeug-Cockpit verglichen, in dem der Pilot (Manager) einen
#
# Überblick über die relevanten Informationen zur Steuerung des Flugzeugs (Unternehmen) an-
#
# gezeigt bekommt.
#
#
#
# Es werden in der Regel vier  wesentliche Dimensionen für die Systematisierung der zentralen Erfolgs-
#
# faktoren und Kennzahlen eines Unternehmens bzw. einer Geschäftseinheit vorgeschlagen:
#
#
#
#
#
# ...
#
#
#
# 11.1.1  Aufgaben
#
#
#
# Aufgaben des Bereichs Organisation der Bank:
#
#
#
# •  Analyse von organisatorischen Fragestellungen,
#
#
#
# Erarbeiten von Lösungen und Beraten von Fachbereichen
#
#
#
# •  Erarbeiten von Vorschlägen und Entscheidungsvorlagen zur Optimierung der Aufbau- u.
#
#
#
# Ablauforganisation (z.B. Kompetenzen, Vertretungsregelungen)
#
#
#
# •  Weiterentwickeln und Pflegen des OHBs (z.B. Dokumentieren von Richtlinien)
#
# •  Unterstützen bei der Umsetzung gesetzlicher Änderungen (z.B. MaRisk, IAS)
#
#
#
# 11.1.2  Instrumente (Dokumentation)
#
#
#
#
#
# Organisationshandbuch (OHB)
#
#
#
# Mit dem OHB kommt die Bank den Regelungen der MaRisk nach, die fordern, „… ein Institut
#
# sicherzustellen hat, dass die Geschäftsaktivitäten auf der Grundlage von Organisationsrichtli-
#
# nien betrieben werden. Die Organisationsrichtlinien müssen schriftlich fixiert und den betroffe-
#
# nen Mitarbeitern in geeigneter Weise bekannt gemacht werden. Es ist sicherzustellen, dass sie
#
# den Mitarbeitern in der jeweils aktuellen Fassung zur Verfügung stehen. Die Richtlinien sind bei
#
# Veränderungen der Aktivitäten und Prozesse zeitnah anzupassen“.
#
#
#
#
#
# •  Die schriftlich fixierte Ordnung der Bank wird durch die Organisation in dem File Server
#
#
#
# System gepflegt. Dies beinhaltet die Neueinstellung und Einholung von Vorstandsge-
#
# nehmigungen bei neuen Dokumenten, sowie die Veröffentlichung geänderter Dokumen-
#
# te bzw. die ordnungsgemäße Archivierung.
#
# Die Publizierung der veränderten OHB-Dokumente an die Mitarbeiter erfolgt nach Bedarf
#
# mittels Online-Information.
#
# In dieser werden alle geänderten Dokumente aufgeführt.
#
#
#
# Die Einstellung der Dokumente erfolgt über eine separate Datenbank (Schattendatenbank) des
#
# OHBs. Zusammen mit der Veröffentlichung werden die ersetzten Dokumente automatisch in
#
# eine Archivdatenbank verschoben.
#
# Die inhaltliche Verantwortung für die einzelnen Dokumente obliegt den jeweils verantwortlichen
#
# Fachbereichen, die auch für die Neuerstellung und Aktualisierung zuständig sind. Durch die
#
# Organisation wird regelmäßig, alle 2 Jahre, die Aktualität der Dokumente abgefragt und nach-
#
# gehalten.
#
#
#
# Im OHB werden die folgenden Dokumente hinterlegt:
#
# •  Richtlinien als Word-Dokument zzgl. Anlagen
#
# •  Bankeigene Formulare als Word- oder Excel-Dokument
#
# •  Formulare von Fremdanbietern im PDF-Format
#
# •  Prozesse im PDF-Format
#
#
#
#
#
# Separat werden in der Wissensdatenbank (Intranet) die Anwenderhandbücher und Anleitungen
#
# sowie weitere Informationen im Wikipedia (Intranet) veröffentlicht. Die Zuständigkeit hierbei liegt
#
# bei den jeweils inhaltlich verantwortlichen Fachbereichen. In den OHB Dokumenten wird auf
#
# jeweils ergänzende Dokumente im Intranet verwiesen.
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 44 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
#
#
#
#
#
#
# Organisatorische Fragestellung
#
#
#
# Eine weitere Aufgabe der Organisation beinhaltet die Analyse und das Erarbeiten von Lösun-
#
# gen in Bezug auf organisatorische Fragestellungen in der Bank zum z.B. Festlegung der Zu-
#
# ständigkeiten und Schnittstellen bei neuen oder geänderten Geschäftsprozessen.
#
#
#
# Eine Analyse erfolgt i.d.R. zusammen mit den Fachbereichen.
#
#
#
#
#
# Optimierung Aufbau- u. Ablauforganisation
#
#
#
# Auch ist die Organisation für das Erarbeiten von Vorschlägen und Entscheidungsvorlagen zur
#
# Optimierung der Aufbau- u. Ablauforganisation zuständig.
#
#
#
# Unter Aufbauorganisation fallen u.a.:
#
#
#
# •  Organigramme
#
# •  Vertretungsregelung
#
# •  Kompetenzen
#
# •  Stellenprofile
#
#
#
#
#
# Unter Ablauforganisation werden alle Richtlinien, Formulare und Prozesse subsumiert, die zur
#
# Dokumentation der Arbeitsprozesse dienen.
#
#
#
#
#
# Arbeitsabläufe
#
#
#
# Eine Optimierung der Arbeitsabläufe, im Sinne einer Arbeitsplatzuntersuchung inklusive Erhe-
#
# bung von Zeiten, Mengen und Kosten erfolgt nur in Ausnahmefällen.
#
# Üblicherweise erfolgt eine Dokumentierung der Tätigkeiten und Schnittstellen im Rahmen der
#
# Erstellung von Richtlinien, wobei hierbei auch Zusammenhänge durch die Organisation kritisch
#
# hinterfragt werden.
#
#
#
# Organisatorische/gesetzliche Veränderung
#
#
#
# Änderungen in den Arbeitsabläufen durch Veränderungen in der Aufbaustruktur und in den Pro-
#
# zessabläufen, bedingt durch:
#
# •  gesetzliche Anforderungen,
#
# •
#
# •
#
# werden durch die Fachbereiche oder Entscheidungen der Gesamtbank, ohne Einbindung der
#
# Organisation initiiert und dokumentiert.
#
#
#
#
#
# internen Umstrukturierungen oder
#
# in den IT-Systemen,
#
#
#
# 11.1.3  Fazit
#
#
#
# Dokumentation
#
#
#
# Die aktuelle Struktur zur Dokumentierung (OHB und Anwenderhandbücher) innerhalb der Bank
#
# ist heterogen gewachsen und besteht aus verschiedenen Systemen, die sich nicht dynamisch
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 45 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# miteinander verbinden lassen. Auch werden unterschiedliche, nicht miteinander kompatible,
#
# Programme und Dokumentarten (Word, Excel, PDF) verwendet.
#
#
#
# Durch die Vorhaltung der Informationen in verschiedenen Systemen und Dokumentarten kann
#
# sich der Mitarbeiter keinen schnellen Gesamtüberblick verschaffen sondern muss an verschie-
#
# denen Stellen recherchieren. Zusätzlich kann innerhalb der Dokumente nur auf ergänzende
#
# Stellen verwiesen werden, eine Verknüpfung besteht nicht.
#
#
#
#
#
# 11.2  Handlungsbedarf im Bereich der Bankorganisation
#
#
#
# 11.2.1  Optimierung Ablauforganisation
#
# Eine Optimierung der Ablauforganisation kann durch die Ablösung aller Verwaltungsprozesse
#
# durch ein elektronisches Workflowsystem erreicht werden. Das Workflowsystem ersetzt die bis-
#
# lang papierhaft ausgeführten Prozesse, sowie die in anderen Systemen elektronisch vorhande-
#
# ne Prozesse.
#
#
#
# Die Vorteile aus betriebswirtschaftlicher Sicht sind wie folgt:
#
#
#
# •  Optimierung bestehender Prozesse
#
# •  Schaffung papierloser Arbeitsplätze
#
# •  Erleichterung in der Abwicklung des Tagesgeschäfts
#
# •  Festlegung eindeutiger Bearbeitungszuständigkeiten
#
# •  Definition von Eskalationsstufen
#
# •  Beschleunigung der Durchlaufzeiten
#
# •  Lieferung relevanter Informationen über Quantitäten und Status von Workflows
#
# •  Schaffung von Transparenz
#
# •  Erhöhung Revisionssicherheit
#
# •  Reduktion von Nachfragen und Fehlerfassungen
#
# •  Steigerung der Auskunftsfähigkeit
#
# •  Verbesserung der internen Kommunikation
#
#
#
#
#
#
#
# 11.2.2  Weiterentwicklung OHB
#
# Die Anwenderfreundlichkeit des OHBs soll erhöht werden, in dem die Dokumente (Richtlinien,
#
# Prozesse, Workflows, Handbücher, usw.) dynamisch miteinander verbunden werden. Ziel ist die
#
# Bereitstellung aller benötigten Informationen für das Tagesgeschäft der Mitarbeiter in schneller,
#
# aktueller, übersichtlicher, verständlicher Form zu gewährleisten.
#
#
#
# Dies kann erreicht werden durch:
#
#
#
# •  Ein Portal für alle Dokumente (OHB, Handbücher, Workflows, Prozesse)
#
# •  Ergänzende Verweise auf andere Richtlinien, Prozesse, Formulare, Handbücher, Ge-
#
#
#
# setzestexte sind durch Links miteinander verbunden
#
#
#
# •  Persönliche Anmerkungen können ergänzt werden z.B. auf der Portalseite oder in Do-
#
#
#
# kumenten (Heftnotiz)
#
#
#
# •  Ein Newsletter informiert die Mitarbeiter regelmäßig über generelle Änderungen im e-
#
#
#
# •
#
#
#
# OHB/Portal
#
# Individuelle Anzeige von Änderungen (ein-/ausschaltbar) zum vorherigen Stand in Favo-
#
# riten oder aufgerufen Dokumenten
#
#
#
# •  Direkte Einpflege von Änderungen ist von mehreren Fachbereichen parallel möglich,
#
#
#
# übersichtliche Anzeige/Nachverfolgung der Änderungen
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 46 von 50
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
#
#
#
#
#
#
#
#
# •  Papierlose Abnahme von Änderungen und Versionsdokumentierung
#
# •  Automatische Wiedervorlage- und Überwachungsworkflow für die Dokumentenaktuali-
#
#
#
# sierung
#
#
#
# 11.2.3  Optimierung Aufbauorganisation
#
# Eine Optimierung der Aufbauorganisation und Reduzierung des zeitlichen Aufwands bei Verän-
#
# derungen kann durch eine frühzeitige Einbindung der Organisation erreicht werden. Dies ist
#
# grundsätzlich bei der Schaffung neuer Stellen sowie bei Veränderungen an der Aufbaustruktur
#
# relevant.
#
#
#
# 11.2.4  Mitwirken bei der Umsetzung gesetzlicher Änderungen
#
# Durch eine frühzeitige Einbindung der Organisation durch die Fachbereiche bei der Umsetzung
#
# von Veränderungen können vorab Auswirkungen auf bestehende Prozesse, Dokumentationen
#
# und Schnittstellen erkannt und berücksichtigt sowie die Erstellung notwendiger Dokumentatio-
#
# nen beschleunigt werden.
#
#
#
#
#
# 12
#
# Die IT/Bankorganisation behandelt die Themen Aufbauorganisation, die Vorgehensweise bei
#
# Personalbeschaffung (Sourcing) und –einsatz.
#
# Ziele der IT-Personalstrategie sind:
#
#
#
# IT/Bankorganisation
#
#
#
# (cid:1)  angemessene Personalausstattung
#
# (cid:1)  adäquate Qualifikation der Mitarbeiter
#
# (cid:1)  gezielte, quantitativ ausgewogene Mitarbeiterförderung
#
# (cid:1)  Entwicklungschancen und Perspektiven für die Mitarbeiter.
#
#
#
# 12.1  Organisationsstruktur
#
#
#
# Die derzeitige Ausrichtung der Aufbauorganisation der IT/Bankorganisation sorgt für eine effizi-
#
# ente Struktur und unterstützt dabei folgende Zielsetzungen:
#
# 1.
#
# 2.  Outsourcing von wettbewerbsunkritischen Funktionen und Konzentration auf die Steue-
#
#
#
# Konzentration auf das Inhouse Consulting für die Kernanwendungen der Kernbank
#
#
#
# 3.
#
#
#
# rungsaufgaben
#
# Angemessene Bereichsgröße für eine effiziente Wahrnehmung der Aufgaben und Ver-
#
# antwortlichkeiten der IT/Bankorganisation
#
#
#
#
#
# Voraussetzung für eine erfolgreiche Beibehaltung dieser Organisationsstruktur ist die Qualifizie-
#
# rung der Anwender zur Optimierung des Aufwandes im Bereich der Anwendungsbetreuung, die
#
# durch das Inhouse Consulting ausgeführt werden. Ansonsten droht bei der skizzierten schlan-
#
# ken Aufstellung die Gefahr, dass dauerhaft Grundlast durch externe Berater abgedeckt wird.
#
# Die gleiche Gefahr gilt auch bei einer eventuell erhöhten Fluktuation.
#
#
#
# 12.2  Sourcing
#
#
#
# Ziele der Düsseldorfer Hypothekenbank AG IT/Bankorganisation Sourcing-Strategie und ent-
#
# sprechende Konzepte:
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 47 von 50
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# (cid:1)  Begrenzter Einsatz von eigenem Personal für die Softwareentwicklung
#
#
#
# o  Bevorzugte Nutzung von geeigneter Standard-Software vor Eigenentwicklung
#
# o
#
#
#
# Individualentwicklung nicht nur in Eigenleistung, sondern auch über fremd bezo-
#
# gene Dienstleistungen und Werkstücke
#
#
#
# (cid:1)  Selektives Outtasking, wenn Leistungen nachhaltig nutzbringender zugekauft werden
#
#
#
# können
#
#
#
# o  Regelmäßiges Benchmarking der Services und Entscheidung über deren Erbrin-
#
#
#
# gung in Eigen- bzw. Fremdleistung anhand der Benchmark-Ergebnisse
#
#
#
# o  Bei Fremdbezug wird das langfristige Standing der Lieferanten kontinuierlich be-
#
# obachtet. Ggf. Insourcing oder Verlagerung auf andere Lieferanten bei erkennba-
#
# ren Problemen.
#
#
#
# (cid:1)  Temporärer Aufbau von zusätzlicher Personalkapazität bei Bedarf möglich und längerfris-
#
#
#
# tig benötigtes Know-how ist intern verfügbar
#
#
#
# o  Der Einsatz von externen Beratern bzw. Entwicklern ist nur vorgesehen
#
#
#
# (cid:1)  bei kurzeitig erforderlichem Spezialwissen,
#
# (cid:1)
# zur Vermittlung von Kenntnissen und Fähigkeiten an interne Mitarbeiter
#
# oder
#
# zur Deckung von erhöhtem temporären Personalbedarf, wobei alternativ
#
# die Vergabe von Zeitarbeitsverträgen bei der Düsseldorfer Hypotheken-
#
# bank AG geprüft werden muss.
#
#
#
# (cid:1)
#
#
#
# o  Der Einsatz von Praktikanten ist nur vorgesehen
#
#
#
# (cid:1)  bei standardisierten Vorhaben
#
# (cid:1)
#
#
#
# zur Deckung von erhöhtem temporären Personalbedarf, wobei alternativ
#
# die Vergabe von Zeitarbeitsverträgen bei der Düsseldorfer Hypotheken-
#
# bank AG geprüft werden muss.
#
#
#
# (cid:1)  Anbietung von Leistungen für Dritte
#
#
#
# o  Generell werden keine Leistungen für Dritte angeboten
#
# o  Sollten Anfragen hinsichtlich einer Dienstleistung bestehen, ist die Zustimmung
#
#
#
# der Geschäftsleitung erforderlich.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 12.3  Personalentwicklung
#
#
#
# Die Positionierung der IT/Bankorganisation und die Auswirkungen auf die zukünftigen Anforde-
#
# rungsprofile der IT-Mitarbeiter erfordern grundsätzlich umfassende Ausbildungsmaßnahmen:
#
#
#
# (cid:1)  um die Mitarbeiter für neue Technologien und Standards zu qualifizieren
#
#
#
# (cid:1)  um Aufgaben aus anstehenden Projekten von Externen und Zeitarbeitsvertrags-
#
#
#
# Mitarbeitern auf dauerbeschäftigte Mitarbeiter zu verlagern
#
#
#
# (cid:1)  um die notwendige Steigerung der Innovationsfähigkeit zu erreichen
#
#
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 48 von 50
#
#
#
#
#
#
#
# 13
#
#
#
# IT-Kosten
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
# 13.1  Entwicklung der IT-Kosten
#
#
#
# Die Entwicklung der IT-Kosten ist geprägt von der Geschäftsstrategie der Bank. Der Ausbau der
#
# gewerblichen großvolumigen Immobilienfinanzierung und die Maßnahmen zur Verbesserung
#
# der Ergebnis- und Risikosteuerung der Bank werden mit IT-technischer Unterstützung effektiv
#
# und effizient begleitet.
#
# Ferner ist die Flexibilisierung (service on demand) auch bei der IT-Kostenstruktur voranzutrei-
#
# ben, damit Marktveränderungen bzw. –schwankungen besser Rechnung getragen werden
#
# kann.
#
# Wesentliche Kostentreiber in den Betriebskosten (Kosten IT-Technik) sind dabei die Outsour-
#
# cingkosten des RZ-Betriebes und die Betriebskosten der zentralen Anwendungen im SAP-
#
# Umfeld sowie der Betrieb von PMS.
#
# Nach dem geplanten Ende des Outsourcing-Vertrages mit IBM / IMS im nächsten Jahr ist das
#
# Outsourcing neu zu definieren bzw. zu verhandeln.
#
#
#
#
#
# 13.2  Kostensteuerung
#
#
#
#
#
# Die IT Kosten werden jeweils für das nächste Jahr budgetiert, über 3 Jahre geplant  und monat-
#
# lich seitens der Geschäftsführung überprüft. Darüber hinaus steuert und kontrolliert die IT-
#
# Leitung die Kosten und Leistungen operativ.
#
# Im Rahmen der Definition der neuen IT-Strategie wird eine weitere Optimierung der Kosten-
#
# steuerung der IT angestrebt. Eine wesentliche Zielsetzung ist dabei die kontinuierliche Erhö-
#
# hung der Kostentransparenz durch eine angemessene Verbesserung der Kostenrechnungssys-
#
# tematik.
#
# In diesem Zusammenhang sind eine Reihe von Maßnahmen bereits geplant oder zur Diskussi-
#
# on gestellt:
#
#
#
# •  Die IT-Kosten werden dahingehend qualifiziert, dass erkennbar ist, welche IT-Kosten für
#
#
#
# den laufenden Betrieb erforderlich sind und welche zur Weiterentwicklung der Ge-
#
# schäftsbereiche eingesetzt werden können. Damit kann ein unmittelbarer Anteil der IT
#
# zur Wertschöpfung des Unternehmens gemessen werden.
#
#
#
# •  Um eine fundierte Kosten/Nutzen-Betrachtung von zukünftigen IT-Anforderungen vor-
#
# nehmen zu können, ist eine Transparenz über damit verbundene Prozesskosten erfor-
#
# derlich.
#
#
#
# •  Es ist zu prüfen, inwiefern eine Leistungsverrechnung von Standardstückkosten für IT-
#
# Leistungen, die in den Outsourcing-Abkommen relativ transparent vorliegen, mit den
#
# Fachbereichen erfolgen kann. Im ersten Schritt ist dies für die allgemeine Arbeitsplatz-
#
# ausstattung (Standard-Arbeitsplatz, mobiler Arbeitsplatz) zu prüfen und ggf. auf Hand-
#
# helds und Mobiltelefon erweiterbar.
#
#
#
# Mittelfristig ist aber zu prüfen, inwieweit eine weitere Kostenaufteilung und -zuordnung möglich
#
# und sinnvoll ist. In diesem Zusammenhang sind alle Kosten auf dem Prüfstand und diesbezüg-
#
# lich zu hinterfragen.
#
# Die genannten Maßnahmen zur Optimierung der Kostensteuerung erhöhen die Transparenz
#
# über die IT-Kosten und bilden zugleich eine Grundlage für die Vergleichbarkeit von IT-Kosten
#
# und ein Benchmarking der Kostenstruktur am Markt.
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 49 von 50
#
#
#
#
#
#
#
#
#
#
#
# IT -Strategie
#
#
#
#
#
# Aufgrund der Umstellung auf die Standardsoftware SAP als auch der Auslagerung zur IBM /
#
# IMS und IKB Data konnten sowohl die Kosten deutlich gesenkt werden als auch die Qualität
#
# und Zukunftssicherheit deutlich erhöht werden.
#
#
#
#
#
#
#
# Stand: 30.06.2014
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Seite 50 von 50

# %%
import textblob_de
import re

# %%
clean_1 = re.sub(r"\n", "", file_contents)

# %%
clean_1
# Out:
# '    __________________________________________________________________________             IT_Strategie           Stand: 30.06.2014 \x0c IT _Strategie                                  INHALT 1  MANAGEMENT SUMMARY ..................................................................................... 6 2  KAPITELÜBERSICHT .............................................................................................. 8 3  SITUATION DER ABTEILUNG INFORMATIONSMANAGEMENT UND BANKBETRIEB............................................................................................................... 9 3.1  Organisationsstruktur und Personal ............................................................................ 9 3.2 IT_Anwendungs_Architektur .......................................................................................... 9 3.3 IT_Infra_Architektur ....................................................................................................... 12 3.4  Kosten........................................................................................................................... 12 3.5  Handlungsbedarf ......................................................................................................... 12 4  STRATEGISCHE ZIELE UND MAßNAHMEN DER DÜSSELDORFER HYPOTHEKENBANK AG ............................................................................................. 14 4.1  Generelle Ziele ............................................................................................................. 14 4.2  Geschäftsspezifische Ziele ......................................................................................... 14 4.3  Umsetzung ................................................................................................................... 15 4.4  Auswirkungen auf die IT_Struktur ............................................................................... 15 5 IT_INFRASTRUKTUR_ARCHITEKTUR .................................................................. 17 5.1 Software as a Service / Cloud ..................................................................................... 17 5.2  Web 2.0 ......................................................................................................................... 18 5.3 ITIL ................................................................................................................................ 19 5.4  Kennzahlen (Key Performance Indicators) ................................................................. 19 5.5 Service_ und Produktkatalog ....................................................................................... 21 6 IT_ANWENDUNGSARCHITEKTUR ....................................................................... 23 6.1  Grundlegende Prinzipien ............................................................................................. 23 6.2 IT_Bebauungsplan (siehe Anlage) ............................................................................... 23 6.3 SAP_Anwendungen ...................................................................................................... 23  Stand: 30.06.2014      Seite 2 von 50 \x0c  IT _Strategie                                 6.4  Business Warehouse ................................................................................................... 24 6.5 SEPA_Fähigkeit ............................................................................................................ 24 6.6 PMS ............................................................................................................................... 25 6.7  Marktdatenversorgung ................................................................................................ 27 Reuters .................................................................................................................................... 27 Bloomberg ................................................................................................. ...
